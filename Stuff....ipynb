# %%
import urllib
import json
serviceurl = 'http://maps.googleapis.com/maps/api/geocode/json?'
while True:
    address = raw_input('Enter location: ') 
    if len(address) < 1: 
        break
    url = serviceurl + urllib.urlencode({'sensor':'false', 'address': address})
    print 'Retrieving', url
    uh = urllib.urlopen(url)
    data = uh.read()
    print 'Retrieved',len(data),'characters'
    try: 
        js = json.loads(str(data))
    except: 
        js = None
    if 'status' not in js or js['status'] != 'OK':
        print '==== Failure To Retrieve ====' 
        print data
        continue
    print json.dumps(js, indent=4)
    lat = js["results"][0]["geometry"]["location"]["lat"] 
    lng = js["results"][0]["geometry"]["location"]["lng"] 
    print 'lat',lat,'lng',lng
    location = js['results'][0]['formatted_address'] 
    print location
# Out:
# Enter location: Tjalleberd
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Tjalleberd
# Retrieved 1902 characters
# {
#     "status": "OK",
#     "results": [
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 53.0386191,
#                         "lng": 5.9736514
#                     },
#                     "southwest": {
#                         "lat": 52.9818162,
#                         "lng": 5.9144324
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 53.0386191,
#                         "lng": 5.9736514
#                     },
#                     "southwest": {
#                         "lat": 52.9818162,
#                         "lng": 5.9144324
#                     }
#                 },
#                 "location": {
#                     "lat": 52.9978296,
#                     "lng": 5.9432282
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Tjalleberd",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Tjalleberd"
#                 },
#                 {
#                     "long_name": "Heerenveen",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Heerenveen"
#                 },
#                 {
#                     "long_name": "Friesland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Frater"
#                 },
#                 {
#                     "long_name": "Netherlands",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "NL"
#                 },
#                 {
#                     "long_name": "8458",
#                     "types": [
#                         "postal_code_prefix",
#                         "postal_code"
#                     ],
#                     "short_name": "8458"
#                 }
#             ],
#             "place_id": "ChIJ889U2BRZyEcRS5nvoJdAPqs",
#             "formatted_address": "8458 Tjalleberd, Netherlands",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ]
# }
# lat 52.9978296 lng 5.9432282
# 8458 Tjalleberd, Netherlands
# Enter location: Øsa bamble
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=%C3%98sa+bamble
# Retrieved 52 characters
# ==== Failure To Retrieve ====
# {
#    "results" : [],
#    "status" : "ZERO_RESULTS"
# }
#
# Enter location: øsa
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=%C3%B8sa
# Retrieved 22081 characters
# {
#     "status": "OK",
#     "results": [
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 40.5649378,
#                         "lng": 72.8613282
#                     },
#                     "southwest": {
#                         "lat": 40.4754848,
#                         "lng": 72.7557564
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.5649378,
#                         "lng": 72.8613282
#                     },
#                     "southwest": {
#                         "lat": 40.4754848,
#                         "lng": 72.7557564
#                     }
#                 },
#                 "location": {
#                     "lat": 40.53,
#                     "lng": 72.8
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osh",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osh"
#                 },
#                 {
#                     "long_name": "Kara-Suu District",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Kara-Suu District"
#                 },
#                 {
#                     "long_name": "Osh Province",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Osh Province"
#                 },
#                 {
#                     "long_name": "Kyrgyzstan",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "KG"
#                 }
#             ],
#             "place_id": "ChIJhS5afwGsvTgRlXv0xh3Go-A",
#             "formatted_address": "Osh, Kyrgyzstan",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 57.2944358,
#                         "lng": 55.4904801
#                     },
#                     "southwest": {
#                         "lat": 57.2684121,
#                         "lng": 55.4223298
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 57.2944358,
#                         "lng": 55.4904801
#                     },
#                     "southwest": {
#                         "lat": 57.2684121,
#                         "lng": 55.4223298
#                     }
#                 },
#                 "location": {
#                     "lat": 57.2840834,
#                     "lng": 55.45432460000001
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Osinskiy rayon",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Osinskiy r-n"
#                 },
#                 {
#                     "long_name": "Perm Krai",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Perm Krai"
#                 },
#                 {
#                     "long_name": "Russia",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "RU"
#                 }
#             ],
#             "place_id": "ChIJC-tJAwxL5kMRTUnuanVhKg8",
#             "formatted_address": "Osa, Perm Krai, Russia",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 35.3686054,
#                         "lng": 136.5631442
#                     },
#                     "southwest": {
#                         "lat": 35.3426827,
#                         "lng": 136.5366923
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.3686054,
#                         "lng": 136.5631442
#                     },
#                     "southwest": {
#                         "lat": 35.3426827,
#                         "lng": 136.5366923
#                     }
#                 },
#                 "location": {
#                     "lat": 35.3594548,
#                     "lng": 136.545292
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "sublocality_level_1",
#                         "sublocality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Tarui",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Tarui"
#                 },
#                 {
#                     "long_name": "Fuwa District",
#                     "types": [
#                         "colloquial_area",
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Fuwa District"
#                 },
#                 {
#                     "long_name": "Gifu Prefecture",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Gifu Prefecture"
#                 },
#                 {
#                     "long_name": "Japan",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "JP"
#                 },
#                 {
#                     "long_name": "503-2122",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "503-2122"
#                 }
#             ],
#             "place_id": "ChIJyY-d_8m1A2ARTzcLVdRZQMg",
#             "formatted_address": "Osa, Tarui, Fuwa District, Gifu Prefecture 503-2122, Japan",
#             "types": [
#                 "sublocality_level_1",
#                 "sublocality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.796944,
#                     "lng": 22.686944
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.79829298029149,
#                         "lng": 22.6882929802915
#                     },
#                     "southwest": {
#                         "lat": 39.79559501970849,
#                         "lng": 22.6855950197085
#                     }
#                 },
#                 "location_type": "APPROXIMATE"
#             },
#             "address_components": [
#                 {
#                     "long_name": "Mount Ossa",
#                     "types": [
#                         "natural_feature",
#                         "establishment"
#                     ],
#                     "short_name": "Mount Ossa"
#                 },
#                 {
#                     "long_name": "Nessonas",
#                     "types": [
#                         "administrative_area_level_5",
#                         "political"
#                     ],
#                     "short_name": "Nessonas"
#                 },
#                 {
#                     "long_name": "Tempi",
#                     "types": [
#                         "administrative_area_level_4",
#                         "political"
#                     ],
#                     "short_name": "Tempi"
#                 },
#                 {
#                     "long_name": "Larissa",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ],
#                     "short_name": "Larissa"
#                 },
#                 {
#                     "long_name": "Greece",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "GR"
#                 },
#                 {
#                     "long_name": "400 06",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "400 06"
#                 }
#             ],
#             "place_id": "ChIJjw6FXZ6IpxQRHqjA6ERZoMc",
#             "formatted_address": "Mount Ossa, Nessonas 400 06, Greece",
#             "types": [
#                 "natural_feature",
#                 "establishment"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 39.6652944,
#                         "lng": -2.7554688
#                     },
#                     "southwest": {
#                         "lat": 39.6551442,
#                         "lng": -2.763112
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.6652944,
#                         "lng": -2.7554688
#                     },
#                     "southwest": {
#                         "lat": 39.6551442,
#                         "lng": -2.763112
#                     }
#                 },
#                 "location": {
#                     "lat": 39.661718,
#                     "lng": -2.7593143
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Osa de la Vega",
#                     "types": [
#                         "administrative_area_level_4",
#                         "political"
#                     ],
#                     "short_name": "Osa de la Vega"
#                 },
#                 {
#                     "long_name": "La Mancha",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ],
#                     "short_name": "La Mancha"
#                 },
#                 {
#                     "long_name": "Cuenca",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Cuenca"
#                 },
#                 {
#                     "long_name": "Castilla-La Mancha",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "CM"
#                 },
#                 {
#                     "long_name": "Spain",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "ES"
#                 },
#                 {
#                     "long_name": "16423",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "16423"
#                 }
#             ],
#             "place_id": "ChIJj8klXnUVaA0RImd7-XLp4Kc",
#             "formatted_address": "16423 Osa, Cuenca, Spain",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 33.5440835,
#                         "lng": 130.4431578
#                     },
#                     "southwest": {
#                         "lat": 33.5303073,
#                         "lng": 130.4288179
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.5440835,
#                         "lng": 130.4431578
#                     },
#                     "southwest": {
#                         "lat": 33.5303073,
#                         "lng": 130.4288179
#                     }
#                 },
#                 "location": {
#                     "lat": 33.5360614,
#                     "lng": 130.4367419
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "sublocality_level_1",
#                         "sublocality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Minami Ward",
#                     "types": [
#                         "ward",
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Minami Ward"
#                 },
#                 {
#                     "long_name": "Fukuoka",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Fukuoka"
#                 },
#                 {
#                     "long_name": "Fukuoka Prefecture",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Fukuoka Prefecture"
#                 },
#                 {
#                     "long_name": "Japan",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "JP"
#                 },
#                 {
#                     "long_name": "811-1313",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "811-1313"
#                 }
#             ],
#             "place_id": "ChIJ8Xbu89mQQTURlf835q2XOjo",
#             "formatted_address": "Osa, Minami Ward, Fukuoka, Fukuoka Prefecture 811-1313, Japan",
#             "types": [
#                 "sublocality_level_1",
#                 "sublocality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 50.98042599999999,
#                         "lng": 24.5746681
#                     },
#                     "southwest": {
#                         "lat": 50.94614199999999,
#                         "lng": 24.519324
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 50.98042599999999,
#                         "lng": 24.5746681
#                     },
#                     "southwest": {
#                         "lat": 50.94614199999999,
#                         "lng": 24.519324
#                     }
#                 },
#                 "location": {
#                     "lat": 50.963333,
#                     "lng": 24.546944
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Turiis'kyi district",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Turiis'kyi district"
#                 },
#                 {
#                     "long_name": "Volyns'ka oblast",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Volyns'ka oblast"
#                 },
#                 {
#                     "long_name": "Ukraine",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "UA"
#                 }
#             ],
#             "place_id": "ChIJDSsHxGFFJEcRaDT-9A_GKBU",
#             "formatted_address": "Osa, Volyns'ka oblast, Ukraine",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 53.388228,
#                         "lng": 103.8853672
#                     },
#                     "southwest": {
#                         "lat": 53.38222,
#                         "lng": 103.8771924
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 53.388228,
#                         "lng": 103.8853672
#                     },
#                     "southwest": {
#                         "lat": 53.38222,
#                         "lng": 103.8771924
#                     }
#                 },
#                 "location": {
#                     "lat": 53.38543869999999,
#                     "lng": 103.8810476
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Osinskiy rayon",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Osinskiy r-n"
#                 },
#                 {
#                     "long_name": "Irkutskaya oblast'",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Irkutskaya oblast'"
#                 },
#                 {
#                     "long_name": "Russia",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "RU"
#                 },
#                 {
#                     "long_name": "669200",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "669200"
#                 }
#             ],
#             "place_id": "ChIJV2jePUDOAF0RPw7YQF_Fogk",
#             "formatted_address": "Osa, Irkutskaya oblast', Russia, 669200",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 60.5885255,
#                     "lng": 7.0334686
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 60.5898744802915,
#                         "lng": 7.034817580291502
#                     },
#                     "southwest": {
#                         "lat": 60.58717651970849,
#                         "lng": 7.032119619708498
#                     }
#                 },
#                 "location_type": "APPROXIMATE"
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Ulvik",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Ulvik"
#                 },
#                 {
#                     "long_name": "Hordaland",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Hordaland"
#                 },
#                 {
#                     "long_name": "Norway",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "NO"
#                 }
#             ],
#             "place_id": "ChIJD72KgYJvPkYRa1hWA24H1F8",
#             "formatted_address": "Osa, Norway",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 25.18921,
#                         "lng": 81.7344299
#                     },
#                     "southwest": {
#                         "lat": 25.16698,
#                         "lng": 81.6843701
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.18921,
#                         "lng": 81.7344299
#                     },
#                     "southwest": {
#                         "lat": 25.16698,
#                         "lng": 81.6843701
#                     }
#                 },
#                 "location": {
#                     "lat": 25.1786812,
#                     "lng": 81.7103155
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Allahabad",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Allahabad"
#                 },
#                 {
#                     "long_name": "Uttar Pradesh",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "UP"
#                 },
#                 {
#                     "long_name": "India",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "IN"
#                 },
#                 {
#                     "long_name": "212106",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "212106"
#                 }
#             ],
#             "place_id": "ChIJScemWzw7hTkRzGs205JM0BM",
#             "formatted_address": "Osa, Uttar Pradesh 212106, India",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 21.3742018,
#                         "lng": 70.0619388
#                     },
#                     "southwest": {
#                         "lat": 21.369366,
#                         "lng": 70.056703
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 21.3742018,
#                         "lng": 70.0619388
#                     },
#                     "southwest": {
#                         "lat": 21.369366,
#                         "lng": 70.056703
#                     }
#                 },
#                 "location": {
#                     "lat": 21.3718488,
#                     "lng": 70.0599902
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Junagadh",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Junagadh"
#                 },
#                 {
#                     "long_name": "Gujarat",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "GJ"
#                 },
#                 {
#                     "long_name": "India",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "IN"
#                 },
#                 {
#                     "long_name": "362230",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "362230"
#                 }
#             ],
#             "place_id": "ChIJWepLfeZf_TsRgieNT434KDw",
#             "formatted_address": "Osa, Gujarat 362230, India",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 25.5106401,
#                         "lng": 81.39591999999999
#                     },
#                     "southwest": {
#                         "lat": 25.4754499,
#                         "lng": 81.35289999999999
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.5106401,
#                         "lng": 81.39591999999999
#                     },
#                     "southwest": {
#                         "lat": 25.4754499,
#                         "lng": 81.35289999999999
#                     }
#                 },
#                 "location": {
#                     "lat": 25.4946055,
#                     "lng": 81.37568619999999
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Osa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Osa"
#                 },
#                 {
#                     "long_name": "Kaushambi",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Kaushambi"
#                 },
#                 {
#                     "long_name": "Uttar Pradesh",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "UP"
#                 },
#                 {
#                     "long_name": "India",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "IN"
#                 },
#                 {
#                     "long_name": "212207",
#                     "types": [
#                         "postal_code"
#                     ],
#                     "short_name": "212207"
#                 }
#             ],
#             "place_id": "ChIJy6OLP9AtmzkR-ybtfa8eH_w",
#             "formatted_address": "Osa, Uttar Pradesh 212207, India",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ]
# }
# lat 40.53 lng 72.8
# Osh, Kyrgyzstan
# Enter location: utrecht
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=utrecht
# Retrieved 1728 characters
# {
#     "status": "OK",
#     "results": [
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 52.1422624,
#                         "lng": 5.1952072
#                     },
#                     "southwest": {
#                         "lat": 52.02611109999999,
#                         "lng": 4.9697758
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 52.1422624,
#                         "lng": 5.1952072
#                     },
#                     "southwest": {
#                         "lat": 52.02611109999999,
#                         "lng": 4.9697758
#                     }
#                 },
#                 "location": {
#                     "lat": 52.09073739999999,
#                     "lng": 5.1214201
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Utrecht",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Utrecht"
#                 },
#                 {
#                     "long_name": "Utrecht",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Utrecht"
#                 },
#                 {
#                     "long_name": "Utrecht",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "UT"
#                 },
#                 {
#                     "long_name": "Netherlands",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "NL"
#                 }
#             ],
#             "place_id": "ChIJNy3TOUNvxkcR6UqvGUz8yNY",
#             "formatted_address": "Utrecht, Netherlands",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ]
# }
# lat 52.0907374 lng 5.1214201
# Utrecht, Netherlands
