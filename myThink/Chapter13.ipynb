# %%
import string

def process_file(filename, skip_header):
    """Makes a histogram that contains the words from a file.

    filename: string
    skip_header: boolean, whether to skip the Gutenberg header
   
    Returns: map from each word to the number of times it appears.
    """
    hist = {}
    fp = file(filename)

    if skip_header:
        skip_gutenberg_header(fp)

    for line in fp:
        #print line
        process_line(line, hist)
    return hist


def skip_gutenberg_header(fp):
    """Reads from fp until it finds the line that ends the header.

    fp: open file object
    """
    for line in fp:
        if line.startswith('*END*THE SMALL PRINT!'):
            break


def process_line(line, hist):
    """Adds the words in the line to the histogram.

    Modifies hist.

    line: string
    hist: histogram (map from word to frequency)
    """
    # replace hyphens with spaces before splitting
    line = line.replace('-', ' ')
    
    for word in line.split():
        # remove punctuation and convert to lowercase
        word = word.strip(string.punctuation + string.whitespace)
        word = word.lower()

        # update the histogram
        hist[word] = hist.get(word, 0) + 1

# %%
hist = process_file('jane_austen_pride_and_prejudice.txt', False)

# %%
def word_frequency(hist):
    #count number of words and the frequency for each word
    #the hist keys are the unique words, and is values are the number of times it is used
    numberofwords, uniquewords = 0, 0
    for word, val in hist.iteritems():
        uniquewords += 1
        numberofwords += val
    return (uniquewords, numberofwords)

# %%
uniquewords, numberofwords = word_frequency(hist)
print uniquewords, numberofwords
# Out:
# 6729 125324

# %%
def top_20_words(hist):
    #prints the 20 most used words
    #maps from hist (key=word,value=freq) to list [((freq,word))]
    word_list = []
    for word, count in hist.iteritems():
        word_list.append((count,word))
    word_list.sort(reverse=True)
    for count, word in word_list[:20]:
        print word, count

# %%
top_20_words(hist)
# Out:
# the 4506
# to 4243
# of 3730
# and 3658
# her 2225
# i 2069
# a 2011
# in 1937
# was 1847
# she 1710
# that 1594
# it 1550
# not 1450
# you 1427
# he 1338
# his 1271
# be 1260
# as 1192
# had 1177
# with 1100

# %%
def read_words(f):
    word_dict = {}
    fin = open(f)
    for line in fin:
        word_dict[line.strip()]=1
    return word_dict

# %%
known_words = read_words('words.txt')

# %%
def unknown_words(book, known_words):
    #compares book and known_words and assembles dictionary of words that are not in known_words
    unknown = {}
    for word in book:
        if not word in known_words:
            unknown[word] = None
    return unknown

# %%
unknowns = unknown_words(hist, known_words)

# %%
print unknowns
# Out:
# {'': None, 'rencontre': None, 'expostulation': None, 'expence': None, "jane's": None, 'synonymously': None, "daughter's": None, 'bakewell': None, '99712': None, "friend's": None, 'prognostics': None, 'superciliousness': None, 'apartment': None, 'essentials': None, 'unenforceability': None, 'fitzwilliam': None, 'thursday': None, 'neighbours': None, 'tm': None, 'dissatisfied': None, 'gratulation': None, 'repinings': None, 'downloading': None, 'unabashed': None, 'covies': None, "women's": None, 'chamberlayne': None, 'recollected': None, "anne's": None, 'cheapside': None, 'ceaseless': None, 'michael': None, 'p': None, 'desertion': None, 'delightfully': None, 'harriet': None, 's/he': None, 'edw': None, "kitty's": None, 'designedly': None, 'abominably': None, '596': None, 'diffuseness': None, 'honourable': None, '4557': None, "gardiner's": None, 'pemberley': None, 'richard': None, "other's": None, 'irrevocably': None, 'eliza': None, 'hatefully': None, "man's": None, "housekeeper's": None, 'christian': None, 'forsters': None, 'favourably': None, "georgiana's": None, 'behaviour': None, 'favourable': None, 'pratt': None, 'phillipses': None, 'november': None, "miller's": None, '39': None, 'substance': None, 'disclaimers': None, '33': None, '32': None, '31': None, '30': None, '37': None, "foundation's": None, '35': None, "person's": None, "anybody's": None, "fool's": None, 'unpleasing': None, "i'm": None, "evening's": None, "day's": None, 'criticise': None, "niece's": None, "caroline's": None, 'georgiana': None, 'unappeasable': None, 'newby': None, "sister's": None, 'lizzy': None, 'sarah': None, 'agreeably': None, 'denominated': None, 'confidante': None, 'complaisant': None, 'edward': None, '6': None, 'feelingly': None, "bingley's": None, "grantley's": None, "lydia's": None, 'http://pglaf.org': None, 'overhearings': None, 'http://www.gutenberg.org': None, 'transient': None, "nephew's": None, 'distractedly': None, '90': None, 'unblemished': None, 'f': None, '1998': None, 'tremblings': None, 'london': None, 'mr': None, "favourite's": None, "phillip's": None, 'expressively': None, 'unshackled': None, 'deservedly': None, 'reanimated': None, 'f3': None, "servant's": None, 'expeditiously': None, 'unpretending': None, 'pointedly': None, "performer's": None, 'reynolds': None, 'undeceive': None, 'influenced': None, 'unreserved': None, 'inhabitants': None, 'robinson': None, "tm's": None, "james's": None, '1': None, 'sunday': None, '1.e.9': None, '1.e.8': None, '1.e.5': None, '1.e.4': None, '1.e.7': None, '1.e.6': None, '1.e.1': None, '1.e.3': None, '1.e.2': None, 'elizabeth': None, 'impartial': None, 'michaelmas': None, '1887': None, 'a': None, "wickham's": None, 'prepossession': None, 'endeavoured': None, 'st': None, '18th': None, 'favourites': None, 'bingley': None, 'disagreeably': None, 'neighbourhoods': None, "don't": None, 'heartfelt': None, 'unsubdued': None, "mary's": None, "won't": None, 'younge': None, "wife's": None, '24': None, '25': None, '26': None, 'imperturbably': None, '20': None, '21': None, '22': None, '23': None, "watson's": None, '28': None, "state's": None, '2015': None, 'admirable': None, "colonel's": None, 'confidently': None, 'non': None, 'recommenced': None, 'condescendingly': None, 'pglaf': None, 'netherfield': None, "regiment's": None, 'hertfordshire': None, "coachman's": None, 'doubtingly': None, 'discomposure': None, 'darcy': None, 'january': None, 'http://www.gutenberg.org/1/3/4/1342': None, "collins's": None, 'denny': None, 'eloquence': None, 'jestingly': None, 'kympton': None, 'prettyish': None, 'england': None, 'slightingly': None, 'discomposed': None, 'ungovernable': None, 'remembrance': None, "earl's": None, 'irremediable': None, "jenkinson's": None, 'saturday': None, 'neighbourhood': None, 'ebooks': None, 'howsoever': None, 'meryton': None, 'undeserved': None, '7': None, "one's": None, 'complimented': None, 'gardiner': None, 'friday': None, 'discompose': None, 'proportioned': None, 'york': None, "people's": None ...

# %%
import random

def make_cdf(hist):
    cdf = []
    for word, count in hist.iteritems():
#        print word
        for i in range(0,count):         
            cdf.append(word)
    return cdf

def choose_from_hist(hist):
    #picks a sample from history, with chance proportional to sample size in histogram
    #e.g. book dictionary, we know number of unique words and the frequency, i.e. total number of words
    #need a 'step'function so we can choose a random int value that alignes with the choice
    #analogy: hist is the pdf, we need a cdf!
    #map pdf to cdf
    #idea: make a list with total words entries, and accumulate the pdf in the cdf list with word x occurrence
    cdf = make_cdf(hist)
    print len(cdf)
#    print cdf[100:110]
    word = random.choice(cdf)
    return word

# %%
choose_from_hist(hist)
# Out:
# 125324
# 'come'

# %%
#More elegant than make_cdf
def random_word(hist):
    """Chooses a random word from a histogram.

    The probability of each word is proportional to its frequency.
    """
    t = []
    for word, freq in hist.items():
        t.extend([word] * freq)
    print len(t)

    return random.choice(t)

# %%
random_word(hist)
# Out:
# 125324
# 'room'

# %% [markdown]
# ## 13.8 Markov Analysis (below wrong, is based on word length, not # of words

# %%
def wordfilter(filename, wordlength):
    #opens the book, start reading lines, keep memory of previous line
    #for each word, check if wordlength = filter
    fp = file(filename)
#    if skip_header:
#        skip_gutenberg_header(fp)
    prev_word = ''
    get_suffix = False
    prefix = {}
    for this_line in fp:    
        this_line = this_line.replace('-', ' ')
        for this_word in this_line.split():
            # remove punctuation and convert to lowercase
            this_word = this_word.strip(string.punctuation + string.whitespace)
            this_word = this_word.lower()
            #print this_word
            if get_suffix:
                if prev_word not in prefix:
                    prefix[prev_word] = [this_word]
                else:
                    prefix[prev_word].append(this_word)
            get_suffix = len(this_word) == wordlength
            if get_suffix:
                prev_word = this_word        
    return prefix

# %%
prefix = wordfilter('jane_austen_pride_and_prejudice.txt',3)

# %%
prefix
# Out:
# {'1.a': ['by'],
#  '1.b': ['project'],
#  '1.c': ['below', 'the'],
#  '1.d': ['the'],
#  '1.e': ['below', 'unless'],
#  '1.f': ['1.f.1'],
#  '596': ['1887'],
#  '801': ['596'],
#  '809': ['north'],
#  'act': ['of', 'in', 'of', 'in', 'as', 'as', 'against', 'in', 'do'],
#  'add': ['to',
#   'something',
#   'very',
#   'considerably',
#   'that',
#   'god',
#   'that',
#   'aught',
#   'something',
#   'i',
#   'a',
#   'force'],
#  'age': ['two',
#   'i',
#   'her',
#   'she',
#   'to',
#   'since',
#   'of',
#   'with',
#   'i',
#   'are',
#   'with',
#   'and',
#   'howsoever',
#   'and',
#   'did'],
#  'ago': ['i',
#   'i',
#   'to',
#   'exactly',
#   'before',
#   'he',
#   'from',
#   'and',
#   'she',
#   'asserted',
#   'i',
#   'i',
#   'would',
#   'and',
#   'attributed',
#   'the',
#   'she',
#   'would',
#   'governess',
#   'never',
#   'was',
#   'every',
#   'oh',
#   'i',
#   'i',
#   'i'],
#  'aid': ['he'],
#  'air': ['of',
#   'and',
#   'of',
#   'and',
#   'and',
#   'was',
#   'as',
#   'all',
#   'and',
#   'of',
#   'of',
#   'for',
#   'of',
#   'more',
#   'with',
#   'of',
#   'the',
#   'was',
#   'which',
#   'and',
#   'was',
#   'and',
#   'and',
#   'of',
#   'of',
#   'of',
#   'and',
#   'altogether',
#   'gloomy',
#   'more'],
#  'all': ['about',
#   'silly',
#   'mr',
#   'mrs',
#   'the',
#   'that',
#   'and',
#   'the',
#   'mr',
#   'his',
#   'the',
#   'that',
#   'he',
#   'indeed',
#   'worth',
#   'the',
#   'the',
#   'the',
#   'attention',
#   'come',
#   'that',
#   'probability',
#   'begin',
#   'my',
#   'conversation',
#   'i',
#   'shake',
#   'politeness',
#   'those',
#   'astonishment',
#   'was',
#   'and',
#   'that',
#   'of',
#   'night',
#   'her',
#   'the',
#   'in',
#   'very',
#   'this',
#   'i',
#   'but',
#   'the',
#   'her',
#   'why',
#   'lost',
#   'he',
#   'my',
#   'cheapside',
#   'till',
#   'that',
#   'my',
#   'are',
#   'young',
#   'of',
#   'paint',
#   'this',
#   'this',
#   'this',
#   'this',
#   'this',
#   'conversation',
#   'the',
#   'advisable',
#   'attended',
#   'indeed',
#   'miss',
#   'to',
#   'the',
#   'means',
#   'the',
#   'and',
#   'with',
#   'there',
#   'aimed',
#   'understand',
#   'was',
#   'plague',
#   'took',
#   'assembled',
#   'its',
#   'out',
#   'and',
#   'families',
#   'in',
#   'my',
#   'chance',
#   'its',
#   'as',
#   'offended',
#   'but',
#   'the',
#   'very',
#   'his',
#   'were',
#   'wondered',
#   'the',
#   'astonishment',
#   'mr',
#   'taken',
#   'the',
#   'the',
#   'among',
#   'in',
#   'liked',
#   'know',
#   'the',
#   'her',
#   'that',
#   'claim',
#   'his',
#   'his',
#   'he',
#   'his',
#   'of',
#   'her',
#   'the',
#   'the',
#   'her',
#   'to',
#   'and',
#   'my',
#   'that',
#   'her',
#   'the',
#   'to',
#   'the',
#   'his',
#   'sir',
#   'i',
#   'his',
#   'his',
#   'is',
#   'in',
#   'matters',
#   'and',
#   'the',
#   'night',
#   'the',
#   'mr',
#   'grateful',
#   'her',
#   'the',
#   'his',
#   'that',
#   'disapprove',
#   'praise',
#   'in',
#   'likelihood',
#   'in',
#   'possible',
#   'her',
#   'and',
#   'of',
#   'she',
#   'her',
#   'the',
#   'liable',
#   'your',
#   'reprehensible',
#   'and',
#   'the',
#   'the',
#   'the',
#   'i',
#   'wish',
#   'these',
#   'this',
#   'that',
#   'means',
#   'wishing',
#   'means',
#   'getting',
#   'was',
#   'the',
#   'astonished',
#   'of',
#   'imaginable',
#   'reconciled',
#   'and',
#   'their',
#   'and',
#   'forgive',
#   'the',
#   'people',
#   "jane's",
#   'this',
#   'this',
#   'let',
#   'for',
#   'settled',
#   'this',
#   'others',
#   'be',
#   'i',
#   'extraordinary',
#   'the',
#   'human',
#   'the',
#   'the',
#   'expect',
#   'that',
#   'her',
#   'been',
#   'there',
#   'for',
#   'our',
#   'unless',
#   'but',
#   'expect',
#   'comparison',
#   'that',
#   'the',
#   'to',
#   'comprehend',
#   'cared',
#   'this',
#   'expectation',
#   'but',
#   'this',
#   'manner',
#   'or',
#   'this',
#   'my',
#   'was',
#   'those',
#   'i',
#   'thank',
#   'take',
#   'fear',
#   'that',
#   'out',
#   'her',
#   'his',
#   'that',
#   'the',
#   'the',
#   'affability',
#   'done',
#   'about',
#   'cried',
#   'this',
#   'surprised',
#   'sent',
#   'the',
#   'the',
#   'dinner',
#   'told',
#   'the',
#   'learn',
#   'to',
#   'play',
#   'what',
#   'the',
#   'all',
#   'what',
#   'five',
#   'that',
#   'the',
#   'right',
#   'felt',
#   'subjects',
#   'this',
#   'that',
#   'amiss',
#   'the',
#   'home',
#   'impertinent',
#   'the',
#   'quitted',
#   'after',
#   'field',
#   'that',
#   'her',
#   'chapter',
#   'the',
#   'do',
#   'conjecture',
#   'that',
#   'that',
#   'loveliness',
#   'the',
#   'and',
#   'that',
#   'and',
#   'that',
#   'compassion',
#   'his',
#   'the',
#   'this',
#   'the',
#   'parties',
#   'the',
#   'claim',
#   'connection',
#   'restraint',
#   'this',
#   'of',
#   'pride',
#   'that',
#   'pretensions',
#   'his',
#   'his',
#   'to',
#   'kindness',
#   'those',
#   'herself',
#   'the',
#   'her',
#   'blame',
#   'the',
#   'the',
#   'their',
#   'her',
#   'added',
#   'there',
#   'mamma',
#   'things',
#   'like',
#   'had',
#   'their',
#   'crammed',
#   'the',
#   'since',
#   'the',
#   'the',
#   'the',
#   'to',
#   'the',
#   'the',
#   'in',
#   'surprise',
#   "darcy's",
#   'done',
#   'the',
#   'the',
#   'found',
#   'its',
#   'the',
#   'her',
#   'her',
#   'a',
#   'the',
#   'their',
#   'sense',
#   'possibility',
#   'the',
#   'which',
#   'restraint',
#   'the',
#   'that',
#   'concern',
#   'drawn',
#   'real',
#   'his',
#   'her',
#   'the',
#   'the',
#   'my',
#   'the',
#   'was',
#   'the',
#   'the',
#   'his',
#   'of',
#   'her',
#   'day',
#   'others',
#   'that',
#   'of',
#   'fixed',
#   'that',
#   'for',
#   'and',
#   'pressed',
#   'the',
#   'the',
#   'of',
#   'amazement',
#   "elizabeth's",
#   'and',
#   'dancing',
#   'her',
#   'that',
#   'their',
#   'this',
#   'above',
#   'the',
#   'the',
#   'the',
#   'the',
#   'talk',
#   'eat',
#   'this',
#   'the',
#   "bingley's",
#   'handsome',
#   'and',
#   'the',
#   'were',
#   'the',
#   'that',
#   'their',
#   'well',
#   'gone',
#   'which',
#   'that',
#   'the',
#   'to',
#   'her',
#   'all',
#   'too',
#   'love',
#   'soon',
#   'surprise',
#   'astonishment',
#   'too',
#   'were',
#   'three',
#   'settled',
#   'settled',
#   'employment',
#   'their',
#   'the',
#   'this',
#   'know',
#   'this',
#   'alive',
#   'till',
#   'the',
#   'removed',
#   'were',
#   'anguish',
#   'my',
#   'she',
#   'in',
#   'end',
#   'repaired',
#   'my',
#   'the',
#   'exclaimed',
#   'her',
#   'keep',
#   'over',
#   'but',
#   'left',
#   'her',
#   'her',
#   'but',
#   'and',
#   'and',
#   'and',
#   'common',
#   'meryton',
#   'honoured',
#   'probability',
#   'the',
#   'that',
#   'your',
#   'others',
#   'the',
#   'your',
#   'their',
#   'the',
#   'the',
#   'these',
#   'that',
#   'his',
#   'this',
#   'that',
#   'likelihood',
#   'after',
#   'under',
#   'very',
#   'his',
#   'the',
#   'have',
#   'the',
#   'that',
#   'his',
#   'the',
#   'of',
#   'she',
#   'those',
#   'her',
#   'his',
#   'will',
#   'before',
#   'the',
#   'sat',
#   'more',
#   'elizabeth',
#   'their',
#   'returned',
#   'envy',
#   'go',
#   'go',
#   'like',
#   'things',
#   'the',
#   'i',
#   'to',
#   'had',
#   'about',
#   'be',
#   'the',
#   'the',
#   'day',
#   'set',
#   'and',
#   'over',
#   'the',
#   'settled',
#   'he',
#   'this',
#   'this',
#   'this',
#   'money',
#   'the',
#   'the',
#   'please',
#   'round',
#   'the',
#   'this',
#   'my',
#   'going',
#   'i',
#   'this',
#   'the',
#   'i',
#   'see',
#   'said',
#   'your',
#   'the',
#   'and',
#   'she',
#   'the',
#   'their',
#   'the',
#   'her',
#   'her',
#   'rose',
#   'her',
#   'handsome',
#   'love',
#   'for',
#   'her',
#   'must',
#   'this',
#   'going',
#   'their',
#   'my',
#   'his',
#   'his',
#   'he',
#   'his',
#   'the',
#   'night',
#   'forgotten',
#   'if',
#   'her',
#   'intending',
#   'amazement',
#   'is',
#   'able',
#   'likelihood',
#   'his',
#   'his',
#   'you',
#   'are',
#   'more',
#   'the',
#   'that',
#   'his',
#   '',
#   'the',
#   'or',
#   'these',
#   'walking',
#   'my',
#   'the',
#   'your',
#   'i',
#   'her',
#   'my',
#   'that',
#   'the',
#   'my',
#   'when',
#   'that',
#   'the',
#   'his',
#   'to',
#   'amazement',
#   'what',
#   'that',
#   'was',
#   'to',
#   'for',
#   'his',
#   'we',
#   'know',
#   'his',
#   'i',
#   'my',
#   'things',
#   'means',
#   'my',
#   'the',
#   'to',
#   'that',
#   'her',
#   'her',
#   'her',
#   'the',
#   'meeting',
#   'likely',
#   'she',
#   'this',
#   'the',
#   'her',
#   'the',
#   'her',
#   'the',
#   'intercourse',
#   'associated',
#   'the',
#   'the',
#   'the',
#   'copies',
#   'the',
#   'references',
#   'references',
#   'works',
#   'copies',
#   'use',
#   'access',
#   'other',
#   'liability',
#   'liability',
#   'walks',
#   '50',
#   'of'],
#  'and': ['prejudice',
#   'with',
#   'prejudice',
#   'prejudice',
#   'prejudice',
#   'she',
#   'i',
#   'four',
#   'was',
#   'some',
#   'therefore',
#   'the',
#   'see',
#   'lady',
#   'i',
#   'i',
#   'ignorant',
#   'live',
#   'caprice',
#   'twenty',
#   'uncertain',
#   'news',
#   'till',
#   'that',
#   'i',
#   'i',
#   'mrs',
#   'introduce',
#   'after',
#   'her',
#   'therefore',
#   'the',
#   'read',
#   'make',
#   'it',
#   'never',
#   'as',
#   'determining',
#   'distant',
#   'they',
#   'to',
#   'very',
#   'all',
#   'sat',
#   'rode',
#   'already',
#   'consequently',
#   'she',
#   'never',
#   'a',
#   'seven',
#   'a',
#   'when',
#   'another',
#   'gentlemanlike',
#   'easy',
#   'the',
#   'he',
#   'above',
#   'not',
#   'being',
#   'unreserved',
#   'talked',
#   'his',
#   'once',
#   'spent',
#   'everybody',
#   'during',
#   'mr',
#   'there',
#   'there',
#   'i',
#   'turning',
#   'coldly',
#   'enjoy',
#   'elizabeth',
#   'she',
#   'catherine',
#   'lydia',
#   'of',
#   'on',
#   'mr',
#   'danced',
#   'she',
#   'he',
#   'got',
#   'asked',
#   'the',
#   'the',
#   'the',
#   'the',
#   'his',
#   'related',
#   'some',
#   'so',
#   'he',
#   'elizabeth',
#   'i',
#   'me',
#   'i',
#   'agreeable',
#   'it',
#   'nonsense',
#   'make',
#   'say',
#   'so',
#   'keep',
#   'i',
#   'with',
#   'less',
#   'with',
#   'conceited',
#   'of',
#   'were',
#   'meanly',
#   'their',
#   'sometimes',
#   'the',
#   'leave',
#   'into',
#   'the',
#   'took',
#   'darcy',
#   'ductility',
#   'though',
#   'of',
#   'fastidious',
#   'his',
#   'attentive',
#   'as',
#   'no',
#   'from',
#   'her',
#   'liked',
#   'pronounced',
#   'one',
#   'their',
#   'risen',
#   'to',
#   'in',
#   'unshackled',
#   'obliging',
#   'the',
#   'the',
#   'to',
#   'mr',
#   'whether',
#   'which',
#   'his',
#   'he',
#   'i',
#   'had',
#   'i',
#   'that',
#   'pride',
#   'drink',
#   'if',
#   'the',
#   'miss',
#   'though',
#   'the',
#   'could',
#   'to',
#   'was',
#   'a',
#   'it',
#   'does',
#   'jane',
#   'as',
#   'if',
#   'has',
#   'four',
#   'if',
#   'it',
#   'that',
#   'when',
#   'his',
#   'pleasing',
#   'in',
#   'who',
#   'as',
#   'if',
#   'said',
#   'you',
#   'sing',
#   'everybody',
#   'gravely',
#   'i',
#   'before',
#   'accomplishments',
#   'though',
#   'conceited',
#   'unaffected',
#   'mary',
#   'gratitude',
#   'irish',
#   'two',
#   'was',
#   'it',
#   'i',
#   'received',
#   'elizabeth',
#   'called',
#   'taking',
#   'said',
#   'though',
#   'turned',
#   'he',
#   'indeed',
#   'yet',
#   'yet',
#   'desired',
#   'pray',
#   'of',
#   'as',
#   'their',
#   'had',
#   'succeeded',
#   'a',
#   'to',
#   'lydia',
#   'when',
#   'furnish',
#   'however',
#   'happiness',
#   'meryton',
#   'connections',
#   'at',
#   'this',
#   'mr',
#   'made',
#   'her',
#   'mother',
#   'indeed',
#   'if',
#   'i',
#   'captain',
#   'the',
#   'she',
#   'tell',
#   'then',
#   'me',
#   'the',
#   'then',
#   'the',
#   'her',
#   'excepting',
#   'headache',
#   'under',
#   'see',
#   'as',
#   'in',
#   'lydia',
#   'the',
#   'elizabeth',
#   'springing',
#   'finding',
#   'a',
#   'where',
#   'by',
#   'miss',
#   'elizabeth',
#   'in',
#   'kindness',
#   'mr',
#   'doubt',
#   'though',
#   'not',
#   'jane',
#   'when',
#   'elizabeth',
#   'solicitude',
#   'having',
#   'that',
#   'promised',
#   'her',
#   'very',
#   'she',
#   'a',
#   'bring',
#   'at',
#   'amongst',
#   'how',
#   'then',
#   'their',
#   'his',
#   'they',
#   'as',
#   'play',
#   'miss',
#   'impertinence',
#   'added',
#   'her',
#   'the',
#   'i',
#   'alone',
#   'mrs',
#   'i',
#   'mother',
#   'such',
#   'they',
#   'they',
#   'indulged',
#   'sat',
#   'elizabeth',
#   'when',
#   'was',
#   'making',
#   'has',
#   'i',
#   'i',
#   'then',
#   'i',
#   'my',
#   'though',
#   'then',
#   'take',
#   'soon',
#   'stationed',
#   'his',
#   'so',
#   'net',
#   'i',
#   'the',
#   'besides',
#   'manner',
#   'expressions',
#   'to',
#   'taste',
#   'application',
#   'elegance',
#   'miss',
#   'were',
#   'with',
#   'that',
#   'it',
#   'her',
#   'in',
#   'some',
#   'form',
#   'its',
#   'invitation',
#   'three',
#   'suffers',
#   'a',
#   'therefore',
#   'do',
#   'unvarying',
#   'darcy',
#   'public',
#   'when',
#   'i',
#   'twenty',
#   'directed',
#   'easy',
#   'those',
#   'never',
#   'the',
#   'envied',
#   'very',
#   'so',
#   'the',
#   'after',
#   'forced',
#   'say',
#   'soon',
#   'the',
#   'good',
#   'a',
#   'her',
#   'abruptly',
#   'when',
#   'by',
#   'when',
#   'her',
#   'elizabeth',
#   'her',
#   'mr',
#   'miss',
#   'in',
#   'miss',
#   'repeatedly',
#   'mr',
#   'mrs',
#   'was',
#   'his',
#   'was',
#   'pray',
#   'i',
#   'blots',
#   'sometimes',
#   'which',
#   'carelessness',
#   'often',
#   'yet',
#   'can',
#   'yet',
#   'i',
#   'if',
#   'at',
#   'ride',
#   'the',
#   'affection',
#   'ordinary',
#   'friend',
#   'size',
#   'in',
#   'of',
#   'therefore',
#   'want',
#   'miss',
#   'then',
#   'mr',
#   'did',
#   'elizabeth',
#   'after',
#   'more',
#   'while',
#   'yet',
#   'reprehensible',
#   'soon',
#   'cheating',
#   'now',
#   'archness',
#   'darcy',
#   'her',
#   'planning',
#   'if',
#   'if',
#   'impertinence',
#   'aunt',
#   'shape',
#   'the',
#   'elizabeth',
#   'immediately',
#   'appear',
#   'seeing',
#   'elizabeth',
#   'laugh',
#   'she',
#   'said',
#   'warmth',
#   'attention',
#   'she',
#   'talked',
#   'mr',
#   'the',
#   'go',
#   'mrs',
#   'rings',
#   'then',
#   'she',
#   'read',
#   'said',
#   'cast',
#   'said',
#   'as',
#   'soon',
#   'walked',
#   'she',
#   'turning',
#   'take',
#   'unconsciously',
#   'down',
#   'asked',
#   'our',
#   'persevered',
#   'have',
#   'if',
#   'punish',
#   'presence',
#   'as',
#   'uncommon',
#   'the',
#   'best',
#   'good',
#   'nonsense',
#   'inconsistencies',
#   'i',
#   'pride',
#   'pray',
#   'vices',
#   'your',
#   'yours',
#   'the',
#   'darcy',
#   'in',
#   'his',
#   'fearful',
#   'at',
#   'the',
#   'enough',
#   'till',
#   'dislike',
#   'repeatedly',
#   'miss',
#   'more',
#   'though',
#   'would',
#   'when',
#   'embracing',
#   'thought',
#   'was',
#   'almost',
#   'elizabeth',
#   'human',
#   'had',
#   'some',
#   'lydia',
#   'much',
#   'it',
#   'i',
#   'a',
#   'a',
#   'he',
#   'his',
#   'about',
#   'requiring',
#   'i',
#   'elizabeth',
#   'she',
#   'nothing',
#   'i',
#   'very',
#   'my',
#   'since',
#   'beneficence',
#   'be',
#   'ceremonies',
#   'establish',
#   'on',
#   'that',
#   'not',
#   'beg',
#   'your',
#   'shall',
#   'daughters',
#   'friend',
#   'polite',
#   'i',
#   'if',
#   'his',
#   'burying',
#   'what',
#   'self',
#   'lydia',
#   'it',
#   'she',
#   'daughters',
#   'was',
#   'mr',
#   'twenty',
#   'stately',
#   'his',
#   'added',
#   'i',
#   'could',
#   'precipitate',
#   'the',
#   'all',
#   'praised',
#   'his',
#   'he',
#   'that',
#   'therefore',
#   'consideration',
#   'with',
#   'condescension',
#   'had',
#   'had',
#   'had',
#   'civil',
#   'i',
#   'of',
#   'what',
#   'who',
#   'often',
#   'ponies',
#   'by',
#   'you',
#   'that',
#   'it',
#   'it',
#   'though',
#   'arranging',
#   'he',
#   'except',
#   'mr',
#   'when',
#   'a',
#   'begging',
#   'lydia',
#   'after',
#   'before',
#   'if',
#   'to',
#   'said',
#   'her',
#   'promised',
#   'should',
#   'prepared',
#   'the',
#   'miserly',
#   'though',
#   'the',
#   'unexpected',
#   'the',
#   'his',
#   'his',
#   'obsequiousness',
#   'humility',
#   'a',
#   'in',
#   'amiable',
#   'he',
#   'suitableness',
#   'excessively',
#   'disinterested',
#   'established',
#   'for',
#   'leading',
#   'general',
#   'it',
#   'beauty',
#   'trusted',
#   'the',
#   'mr',
#   'have',
#   'there',
#   'garden',
#   'tranquillity',
#   'though',
#   'conceit',
#   'mr',
#   'go',
#   'civil',
#   'nothing',
#   'he',
#   'kitty',
#   'lydia',
#   'fortunately',
#   'entreated',
#   'he',
#   'very',
#   'unassuming',
#   'the',
#   'talking',
#   'darcy',
#   'bingley',
#   'began',
#   'miss',
#   'was',
#   'elizabeth',
#   'rode',
#   'mr',
#   'then',
#   'even',
#   'loudly',
#   'the',
#   'she',
#   'inquiries',
#   'that',
#   'down',
#   'had',
#   'lydia',
#   'their',
#   'give',
#   'mrs',
#   'a',
#   'they',
#   'was',
#   'politeness',
#   'her',
#   'all',
#   'mrs',
#   'his',
#   'the',
#   'was',
#   'they',
#   'admire',
#   'he',
#   'furniture',
#   'who',
#   'found',
#   'would',
#   'her',
#   'the',
#   'he',
#   'who',
#   'who',
#   'examine',
#   'when',
#   'the',
#   'walk',
#   'elizabeth',
#   'the',
#   'the',
#   'was',
#   'muffin',
#   'with',
#   'lydia',
#   'exclaiming',
#   'she',
#   'after',
#   'then',
#   'i',
#   'too',
#   'perhaps',
#   'consequence',
#   'imposing',
#   'sees',
#   'it',
#   'most',
#   'the',
#   'i',
#   'everything',
#   'disgracing',
#   'listened',
#   'speaking',
#   'good',
#   'my',
#   'the',
#   'excellent',
#   'my',
#   'society',
#   'i',
#   'excessively',
#   'thought',
#   'to',
#   'that',
#   'no',
#   'i',
#   'to',
#   'that',
#   'thought',
#   'after',
#   'one',
#   'devoted',
#   'when',
#   'pride',
#   'in',
#   'generous',
#   'relieve',
#   'filial',
#   'careful',
#   'you',
#   'best',
#   'pleasing',
#   'extremely',
#   'i',
#   'hours',
#   'i',
#   'superintends',
#   'many',
#   'saying',
#   'is',
#   'perhaps',
#   'figure',
#   'mr',
#   'mrs',
#   'begged',
#   'happily',
#   'after',
#   'lady',
#   'it',
#   'her',
#   'useless',
#   'her',
#   'her',
#   'that',
#   'that',
#   'insolent',
#   'clever',
#   'fortune',
#   'the',
#   'they',
#   'gave',
#   'whatever',
#   'of',
#   'the',
#   'mr',
#   'mrs',
#   'repeatedly',
#   'herself',
#   'concern',
#   'yet',
#   'nothing',
#   'throw',
#   'now',
#   'his',
#   'repeatedly',
#   'nothing',
#   'hurrying',
#   'was',
#   'the',
#   'elizabeth',
#   'of',
#   'behaviour',
#   'lydia',
#   'a',
#   'even',
#   'i',
#   'amusement',
#   'if',
#   'she',
#   'was',
#   'i',
#   'i',
#   'not',
#   'to',
#   'her',
#   'mr',
#   'of',
#   'heard',
#   'vivacity',
#   'though',
#   'till',
#   'talk',
#   'nothing',
#   'monday',
#   'lydia',
#   'looked',
#   'prepared',
#   'though',
#   'who',
#   'was',
#   'as',
#   'turned',
#   'though',
#   'having',
#   'to',
#   'solemn',
#   'often',
#   'misery',
#   'had',
#   'of',
#   'was',
#   'she',
#   'darcy',
#   'allow',
#   'took',
#   'reading',
#   'she',
#   'at',
#   'was',
#   'you',
#   'assured',
#   'by',
#   'yet',
#   'be',
#   'they',
#   'her',
#   'unable',
#   'elizabeth',
#   'in',
#   'in',
#   'seemed',
#   'his',
#   'that',
#   'bingley',
#   'his',
#   'jane',
#   'said',
#   'what',
#   'never',
#   'what',
#   'i',
#   'they',
#   'parted',
#   'on',
#   'directed',
#   'with',
#   'asking',
#   'i',
#   'that',
#   'i',
#   'his',
#   'of',
#   'the',
#   'at',
#   'everything',
#   'is',
#   'honour',
#   'is',
#   'i',
#   'has',
#   'has',
#   'on',
#   'said',
#   'told',
#   'of',
#   'trust',
#   'that',
#   'when',
#   'those',
#   'habitual',
#   'with',
#   'whose',
#   'though',
#   'saw',
#   'lady',
#   'when',
#   'mr',
#   'at',
#   'moved',
#   'even',
#   'mr',
#   'the',
#   'she',
#   'she',
#   'deeply',
#   'of',
#   'mrs',
#   'so',
#   'living',
#   'then',
#   'to',
#   'lastly',
#   'triumphantly',
#   'blushed',
#   'vexation',
#   'steady',
#   'lady',
#   'chicken',
#   'she',
#   'silent',
#   'she',
#   'she',
#   'her',
#   'saw',
#   'at',
#   'when',
#   'elizabeth',
#   'sorry',
#   'perfectly',
#   'not',
#   'the',
#   'the',
#   'improvement',
#   'i',
#   'conciliatory',
#   'with',
#   'observed',
#   'happy',
#   'her',
#   'that',
#   'mr',
#   'she',
#   'though',
#   'offer',
#   'that',
#   'good',
#   'rejoiced',
#   'by',
#   'her',
#   'were',
#   'by',
#   'his',
#   'the',
#   'politeness',
#   'jane',
#   'talked',
#   'even',
#   'addressed',
#   'he',
#   'quitted',
#   'wedding',
#   'with',
#   'though',
#   'the',
#   'netherfield',
#   'having',
#   'one',
#   'gathering',
#   'upon',
#   'embarrassed',
#   'hearing',
#   'a',
#   'as',
#   'tried',
#   'diversion',
#   'kitty',
#   'as',
#   'moreover',
#   'he',
#   'thirdly',
#   'recommendation',
#   'it',
#   'for',
#   'i',
#   'kindness',
#   'your',
#   'vivacity',
#   'respect',
#   'i',
#   'now',
#   'shall',
#   'that',
#   'you',
#   'that',
#   ...],
#  'any': ['of',
#   'such',
#   'reply',
#   'satisfactory',
#   'other',
#   'compassion',
#   'description',
#   'attention',
#   'to',
#   'husband',
#   'other',
#   'more',
#   'intention',
#   'place',
#   'and',
#   'more',
#   'complacency',
#   'but',
#   'consideration',
#   'are',
#   'service',
#   'apparent',
#   'great',
#   'attention',
#   'man',
#   'other',
#   'woman',
#   'conversation',
#   'reply',
#   'inconvenience',
#   'amends',
#   'degree',
#   'other',
#   'other',
#   'family',
#   'affront',
#   'useful',
#   'prepossession',
#   'more',
#   'previous',
#   'house',
#   'man',
#   'other',
#   'object',
#   'value',
#   'single',
#   'particular',
#   'rate',
#   'evil',
#   'disrespect',
#   'reply',
#   'of',
#   'sort',
#   'pleasure',
#   'third',
#   'notice',
#   'interest',
#   'period',
#   'influence',
#   'young',
#   'time',
#   'disservice',
#   'attempt',
#   'self',
#   'other',
#   'regret',
#   'attempt',
#   'of',
#   'disrespect',
#   'intention',
#   'intention',
#   "woman's",
#   'other',
#   'conception',
#   'return',
#   'charm',
#   'other',
#   'of',
#   'of',
#   'of',
#   "woman's",
#   'other',
#   'answer',
#   'comfort',
#   'excess',
#   'regard',
#   'part',
#   'extenuating',
#   'danger',
#   'alarm',
#   'of',
#   'such',
#   'certainty',
#   'delay',
#   'particular',
#   'sigh',
#   'hesitation',
#   'extraordinary',
#   'of',
#   'likeness',
#   'dish',
#   'intermission',
#   'of',
#   'governess',
#   'of',
#   'refreshment',
#   'of',
#   'consciousness',
#   'invitation',
#   'other',
#   'account',
#   'design',
#   'lady',
#   'other',
#   'other',
#   'symptom',
#   'eligible',
#   'uneasiness',
#   'harm',
#   'other',
#   'other',
#   'objections',
#   'revival',
#   'communication',
#   'consideration',
#   'feeling',
#   'serious',
#   'other',
#   'possible',
#   'repetition',
#   'intention',
#   'other',
#   'other',
#   'apprehension',
#   'symptom',
#   'participation',
#   'share',
#   'rate',
#   'human',
#   'public',
#   'apology',
#   'wish',
#   'contrivance',
#   'could',
#   'message',
#   'alarm',
#   'better',
#   'pleasant',
#   'flirting',
#   'fun',
#   'of',
#   'other',
#   'admiration',
#   'reason',
#   'more',
#   'such',
#   'of',
#   'attraction',
#   'portion',
#   'real',
#   'rate',
#   'time',
#   'of',
#   'of',
#   'dislike',
#   'artificial',
#   'notion',
#   'circumstance',
#   'pleasure',
#   'of',
#   'they',
#   'of',
#   'it',
#   'of',
#   'of',
#   'intercourse',
#   'dislike',
#   'idea',
#   'reference',
#   'other',
#   'indelicate',
#   'peculiarity',
#   'more',
#   'beauty',
#   'pain',
#   'success',
#   'blame',
#   'measure',
#   'partiality',
#   'young',
#   'fear',
#   'father',
#   'terms',
#   'opinions',
#   'one',
#   'danger',
#   'particular',
#   'directions',
#   'reply',
#   'inquiries',
#   'alarm',
#   'idea',
#   'person',
#   'of',
#   'other',
#   'satisfactory',
#   'success',
#   'relations',
#   'other',
#   'information',
#   'relations',
#   'connection',
#   'of',
#   'news',
#   'other',
#   'intention',
#   'remembrance',
#   'message',
#   'or',
#   'sense',
#   'fear',
#   'rate',
#   'of',
#   'meeting',
#   'body',
#   'of',
#   'satisfaction',
#   'young',
#   'displeasure',
#   'silly',
#   'friend',
#   'symptom',
#   'unnecessary',
#   'stay',
#   'of',
#   'of',
#   'i',
#   'design',
#   'other',
#   'time',
#   'impression',
#   'account',
#   'permission',
#   'of',
#   'of',
#   "person's",
#   'person',
#   'possible',
#   'idea',
#   'man',
#   'woman',
#   'other',
#   'consideration',
#   'such',
#   'other',
#   'possible',
#   'credit',
#   'philosophy',
#   'other',
#   'doubt',
#   'other',
#   'young',
#   'of',
#   'attention',
#   'opening',
#   'more',
#   'answer',
#   'congratulations',
#   'place',
#   'purpose',
#   'other',
#   'way',
#   'part',
#   'way',
#   'other',
#   'work',
#   'country',
#   'copy',
#   'work',
#   'fees',
#   'additional',
#   'files',
#   'other',
#   'part',
#   'binary',
#   'word',
#   'alternate',
#   'project',
#   'money',
#   'money',
#   'other',
#   'distributor',
#   'you',
#   'kind',
#   'purpose',
#   'disclaimer',
#   'provision',
#   'agent',
#   'volunteers',
#   'of',
#   'project',
#   'project',
#   'defect',
#   'particular',
#   'statements',
#   'particular'],
#  'apt': ['you'],
#  'are': ['to',
#   'as',
#   'determined',
#   'over',
#   'always',
#   'all',
#   'my',
#   'twenty',
#   'not',
#   'not',
#   'a',
#   'the',
#   'engaged',
#   'cried',
#   'several',
#   'dancing',
#   'slighted',
#   'wasting',
#   'charming',
#   'a',
#   'good',
#   'not',
#   'very',
#   'you',
#   'very',
#   'different',
#   'often',
#   'very',
#   'not',
#   'ever',
#   'to',
#   'severe',
#   'a',
#   'an',
#   'you',
#   'considering',
#   'serious',
#   'silly',
#   'all',
#   'not',
#   'to',
#   'wanted',
#   'they',
#   'wanted',
#   'always',
#   'all',
#   'really',
#   'you',
#   'nothing',
#   'and',
#   'suffered',
#   'the',
#   'mistaken',
#   'few',
#   'brought',
#   'a',
#   'not',
#   'mistaken',
#   'generally',
#   'really',
#   'giving',
#   'too',
#   'in',
#   'you',
#   'charmingly',
#   'you',
#   'not',
#   'in',
#   'conscious',
#   'you',
#   'such',
#   'precisely',
#   'without',
#   'not',
#   'not',
#   'safe',
#   'good',
#   'instituted',
#   'highly',
#   'very',
#   'settled',
#   'all',
#   'better',
#   'not',
#   'always',
#   'the',
#   'the',
#   'interested',
#   'you',
#   'in',
#   'not',
#   'very',
#   'none',
#   'at',
#   'undoubtedly',
#   'much',
#   'dancing',
#   'you',
#   'gratifying',
#   'each',
#   'also',
#   'to',
#   'very',
#   'quite',
#   'much',
#   'not',
#   'certainly',
#   'and',
#   'first',
#   'many',
#   'married',
#   'too',
#   'paying',
#   'who',
#   'so',
#   'briefly',
#   'circumstances',
#   'not',
#   'uniformly',
#   'wanted',
#   'all',
#   'you',
#   'come',
#   'never',
#   'all',
#   'on',
#   'certain',
#   'already',
#   'scarcely',
#   'not',
#   'all',
#   'feeling',
#   'preserved',
#   'too',
#   'really',
#   'hurt',
#   'few',
#   'supposing',
#   'officers',
#   'very',
#   'all',
#   'very',
#   'so',
#   'too',
#   'warned',
#   'not',
#   'seldom',
#   'satisfied',
#   'coming',
#   'not',
#   'even',
#   'young',
#   'not',
#   'the',
#   'young',
#   'never',
#   'which',
#   'not',
#   'most',
#   'quite',
#   'any',
#   'married',
#   'saying',
#   'talking',
#   'you',
#   'speaking',
#   'speaking',
#   'few',
#   'mistaken',
#   'not',
#   'perfectly',
#   'continually',
#   'you',
#   'you',
#   'poor',
#   'home',
#   'not',
#   'you',
#   'sometimes',
#   'rather',
#   'heavy',
#   'mistaken',
#   'not',
#   'the',
#   'never',
#   'neither',
#   'all',
#   'you',
#   'engaged',
#   'sharers',
#   'going',
#   'they',
#   'going',
#   'all',
#   'such',
#   'come',
#   'all',
#   'quite',
#   'we',
#   'scarcely',
#   'not',
#   'mistaken',
#   'not',
#   'known',
#   'known',
#   'very',
#   'wanting',
#   'given',
#   'sufficiently',
#   'connected',
#   'delightful',
#   'just',
#   'very',
#   'lucky',
#   'good',
#   'good',
#   'he',
#   'thus',
#   'some',
#   'perfectly',
#   'and',
#   'not',
#   'not',
#   'tolerable',
#   'not',
#   'all',
#   'now',
#   'not',
#   'such',
#   'not',
#   'very',
#   'gone',
#   'certainly',
#   'they',
#   'good',
#   'they',
#   'not',
#   'naturally',
#   'other',
#   'endless',
#   'you',
#   'greatly',
#   'quite',
#   'you',
#   'not',
#   'not',
#   'not',
#   'married',
#   'the',
#   'i',
#   'packed',
#   'now',
#   'grievously',
#   'never',
#   'a',
#   'looking',
#   'discovered',
#   'married',
#   'not',
#   'willing',
#   'all',
#   'conditions',
#   'not',
#   'generally',
#   'discharged',
#   'two',
#   'really',
#   'to',
#   'forced',
#   'persuaded',
#   'dreadful',
#   'still',
#   'able',
#   'first',
#   'several',
#   'not',
#   'so',
#   'to',
#   'really',
#   'to',
#   'better',
#   'the',
#   'going',
#   'strangely',
#   'brother',
#   'single',
#   'gone',
#   'to',
#   'quite',
#   'in',
#   'very',
#   'that',
#   'very',
#   'provoking',
#   'going',
#   'a',
#   'by',
#   'each',
#   'you',
#   'well',
#   'full',
#   'mistaken',
#   'not',
#   'you',
#   'heavy',
#   'to',
#   'formed',
#   'descended',
#   'destined',
#   'equal',
#   'a',
#   'your',
#   'you',
#   'you',
#   'the',
#   'then',
#   'determined',
#   'you',
#   'about',
#   'not',
#   'too',
#   'still',
#   'unchanged',
#   'not',
#   'now',
#   'joking',
#   'engaged',
#   'you',
#   'you',
#   'to',
#   'you',
#   'you',
#   'you',
#   'you',
#   'determined',
#   'resolved',
#   'about',
#   'under',
#   'to',
#   'all',
#   'a',
#   'a',
#   'in',
#   'located',
#   'removed',
#   'located',
#   'in',
#   'outside',
#   'redistributing',
#   'legally',
#   'set',
#   'critical',
#   'tax',
#   'scattered',
#   'particularly',
#   'not',
#   'gratefully',
#   'accepted',
#   'often',
#   'confirmed'],
#  'arm': ['of', 'in', 'with', 'inadequate'],
#  'art': ['undoubtedly', 'so', 'and'],
#  'ask': ['him',
#   'on',
#   'my',
#   'a',
#   'said',
#   'nothing',
#   'whether',
#   'when',
#   'to',
#   'only',
#   'you',
#   'your',
#   'him',
#   'above',
#   'respecting',
#   'for',
#   'me',
#   '',
#   'too',
#   'her',
#   'of',
#   'for',
#   'what',
#   '',
#   'him',
#   'you',
#   'elizabeth',
#   'them',
#   'questions',
#   'why',
#   'whether',
#   'i'],
#  'ate': ['and', 'pressing', 'and'],
#  'awe': ['his', 'of', 'of'],
#  'aye': ['so', 'because', 'that', 'there', 'no', 'that'],
#  'bad': ['belongs',
#   'day',
#   'cold',
#   'indeed',
#   'as',
#   'enough',
#   'he',
#   'it',
#   'at',
#   'news',
#   'was',
#   'or',
#   'what',
#   'enough',
#   'as'],
#  'bed': ['and', 'if', 'mrs', 'from', 'in'],
#  'beg': ['you',
#   'for',
#   'that',
#   'leave',
#   'your',
#   'your',
#   'you',
#   'leave',
#   'your',
#   'his',
#   'that',
#   'your',
#   'my',
#   'your',
#   'you',
#   'therefore',
#   'to'],
#  'bid': ['by'],
#  'bit': ['better', 'of', 'of'],
#  'bow': ['and',
#   'and',
#   'of',
#   'he',
#   'and',
#   'and',
#   'to',
#   'and',
#   'as',
#   'turned',
#   'her'],
#  'box': ['there'],
#  'boy': ['protested', 'in', 'chapter', 'in'],
#  'but': ['it',
#   'it',
#   'i',
#   'my',
#   'consider',
#   'you',
#   'lizzy',
#   'i',
#   'you',
#   'unable',
#   'if',
#   'knew',
#   'why',
#   'as',
#   'i',
#   'for',
#   'he',
#   'see',
#   'he',
#   'were',
#   'his',
#   'there',
#   'not',
#   'he',
#   'however',
#   'i',
#   'that',
#   'i',
#   'to',
#   'they',
#   'was',
#   'proud',
#   'did',
#   'as',
#   'though',
#   'darcy',
#   'she',
#   'still',
#   'he',
#   'i',
#   'however',
#   'she',
#   'i',
#   'i',
#   'elizabeth',
#   'she',
#   'it',
#   'poor',
#   'there',
#   'he',
#   'she',
#   'if',
#   'though',
#   'the',
#   'these',
#   'you',
#   'with',
#   'it',
#   'no',
#   'if',
#   'it',
#   'as',
#   'i',
#   'his',
#   'in',
#   'considering',
#   'ill',
#   'officers',
#   'i',
#   'lydia',
#   'as',
#   'i',
#   'the',
#   'my',
#   'if',
#   'her',
#   'every',
#   'jane',
#   'him',
#   'being',
#   'this',
#   'with',
#   'it',
#   'his',
#   'suspecting',
#   'i',
#   'i',
#   'i',
#   'half',
#   'in',
#   'she',
#   'being',
#   'a',
#   'to',
#   'intricate',
#   'a',
#   'people',
#   'that',
#   'as',
#   'concern',
#   'everybody',
#   'then',
#   'you',
#   'to',
#   'however',
#   'if',
#   'could',
#   'mrs',
#   'you',
#   'i',
#   'do',
#   'whether',
#   'i',
#   'i',
#   'which',
#   'in',
#   'elizabeth',
#   'made',
#   'i',
#   'i',
#   'there',
#   'their',
#   'elizabeth',
#   'when',
#   'diffuseness',
#   'in',
#   'to',
#   'as',
#   'there',
#   'it',
#   'darcy',
#   'agreed',
#   'he',
#   'two',
#   'depend',
#   'the',
#   'upon',
#   'i',
#   'these',
#   'it',
#   'pride',
#   'they',
#   'you',
#   'mrs',
#   'jane',
#   'their',
#   'good',
#   'it',
#   'if',
#   'for',
#   'of',
#   'the',
#   'that',
#   'mrs',
#   'that',
#   'i',
#   'perhaps',
#   'for',
#   'he',
#   'he',
#   'when',
#   'he',
#   'affability',
#   'she',
#   'on',
#   'mr',
#   'i',
#   'mr',
#   'little',
#   'it',
#   'she',
#   'really',
#   'the',
#   'without',
#   'her',
#   'unluckily',
#   'though',
#   'even',
#   'yet',
#   'when',
#   'to',
#   'mr',
#   'he',
#   'i',
#   'could',
#   'being',
#   'look',
#   'i',
#   'with',
#   'i',
#   'i',
#   'what',
#   'i',
#   'the',
#   'very',
#   'circumstances',
#   'when',
#   'how',
#   'mr',
#   'the',
#   'it',
#   'what',
#   'attribute',
#   'his',
#   'did',
#   'she',
#   'he',
#   'we',
#   'she',
#   'she',
#   'mr',
#   'with',
#   'when',
#   'thanks',
#   'he',
#   'from',
#   'i',
#   'i',
#   'his',
#   'of',
#   'there',
#   'to',
#   'you',
#   'consider',
#   'jane',
#   'in',
#   'elizabeth',
#   'now',
#   'he',
#   'on',
#   'let',
#   'sir',
#   'if',
#   'if',
#   'i',
#   'really',
#   'your',
#   'perhaps',
#   'i',
#   'he',
#   'what',
#   'he',
#   'you',
#   'since',
#   'permit',
#   'her',
#   'three',
#   'no',
#   'not',
#   'in',
#   'jane',
#   'no',
#   'a',
#   'allow',
#   'before',
#   'the',
#   'able',
#   'the',
#   'to',
#   'it',
#   'i',
#   'to',
#   'as',
#   'she',
#   'depend',
#   'i',
#   'if',
#   'hurrying',
#   'smile',
#   'mrs',
#   'jane',
#   'i',
#   'it',
#   'lydia',
#   'we',
#   'by',
#   'his',
#   'elizabeth',
#   'we',
#   'may',
#   'as',
#   'of',
#   'you',
#   'i',
#   'the',
#   'my',
#   'i',
#   'my',
#   'if',
#   'even',
#   "charlotte's",
#   'here',
#   'little',
#   'still',
#   'it',
#   'is',
#   'on',
#   'that',
#   'elizabeth',
#   'when',
#   'she',
#   'incredulous',
#   'sir',
#   'no',
#   'she',
#   'that',
#   'whatever',
#   'as',
#   'his',
#   'her',
#   'at',
#   'i',
#   'said',
#   'that',
#   'myself',
#   'no',
#   'enough',
#   'i',
#   'our',
#   'i',
#   'without',
#   'if',
#   'this',
#   'whatever',
#   'though',
#   'a',
#   'it',
#   'by',
#   'lizzy',
#   'so',
#   'these',
#   'it',
#   'that',
#   'do',
#   'he',
#   'does',
#   'in',
#   'as',
#   'he',
#   'since',
#   'do',
#   'really',
#   'as',
#   'be',
#   'she',
#   'so',
#   'she',
#   'the',
#   'my',
#   'if',
#   'i',
#   'wonder',
#   'i',
#   'not',
#   'her',
#   'she',
#   'slightly',
#   'elizabeth',
#   'my',
#   'charlotte',
#   'as',
#   'she',
#   'my',
#   'he',
#   'there',
#   'perhaps',
#   'though',
#   'in',
#   'of',
#   'the',
#   'well',
#   'you',
#   'lady',
#   'who',
#   'their',
#   'slightly',
#   'just',
#   'whatever',
#   'lady',
#   'she',
#   'eat',
#   'to',
#   'especially',
#   'answered',
#   'otherwise',
#   'i',
#   'my',
#   'such',
#   'that',
#   'a',
#   'the',
#   'really',
#   'her',
#   'his',
#   'when',
#   'she',
#   'was',
#   'herself',
#   'in',
#   'his',
#   'she',
#   'mr',
#   'it',
#   'prepare',
#   'i',
#   'then',
#   'neither',
#   'the',
#   'it',
#   'little',
#   'perhaps',
#   'that',
#   'not',
#   'when',
#   'gentlemen',
#   'why',
#   'without',
#   'the',
#   'she',
#   'absence',
#   'elizabeth',
#   'to',
#   'he',
#   'it',
#   'i',
#   'so',
#   'in',
#   'recovering',
#   'perhaps',
#   'i',
#   'without',
#   'she',
#   'it',
#   'it',
#   'she',
#   'she',
#   'mr',
#   'in',
#   'colonel',
#   'this',
#   'said',
#   'there',
#   'was',
#   'his',
#   'i',
#   'it',
#   'i',
#   'the',
#   'its',
#   'it',
#   'perhaps',
#   'disguise',
#   'he',
#   'his',
#   'the',
#   'on',
#   'with',
#   'i',
#   'from',
#   'it',
#   'without',
#   'i',
#   'i',
#   'there',
#   'amidst',
#   'however',
#   'bingley',
#   'one',
#   'her',
#   'his',
#   'of',
#   'whatever',
#   'at',
#   'his',
#   'on',
#   'last',
#   'fifteen',
#   'i',
#   'i',
#   'his',
#   'i',
#   'such',
#   'haughty',
#   'when',
#   'it',
#   'when',
#   'when',
#   'with',
#   'every',
#   'what',
#   'no',
#   'she',
#   'alas',
#   'the',
#   'that',
#   'herself',
#   'that',
#   'his',
#   'allow',
#   'vanity',
#   'it',
#   'that',
#   'just',
#   'i',
#   'so',
#   'darcy',
#   'if',
#   'it',
#   'my',
#   'i',
#   'when',
#   'she',
#   'while',
#   'i',
#   'i',
#   'on',
#   'one',
#   'she',
#   'he',
#   'a',
#   'jane',
#   'the',
#   'you',
#   'i',
#   'there',
#   'he',
#   'now',
#   'i',
#   'i',
#   'harriet',
#   'colonel',
#   'there',
#   'i',
#   'of',
#   'elizabeth',
#   'his',
#   'still',
#   'consider',
#   'he',
#   'you',
#   'you',
#   'you',
#   'such',
#   'you',
#   'one',
#   'the',
#   'there',
#   'i',
#   'as',
#   'i',
#   'go',
#   'go',
#   'papa',
#   'all',
#   'the',
#   'do',
#   'of',
#   'her',
#   'they',
#   'feel',
#   'with',
#   'i',
#   'checking',
#   'that',
#   'she',
#   'with',
#   'she',
#   'mr',
#   'where',
#   'respecting',
#   'she',
#   'it',
#   'here',
#   'her',
#   'was',
#   'it',
#   'surely',
#   'they',
#   'the',
#   'her',
#   'against',
#   'she',
#   'without',
#   'from',
#   'elizabeth',
#   'no',
#   'had',
#   'we',
#   'i',
#   'elizabeth',
#   'lizzy',
#   'in',
#   'i',
#   'i',
#   'i',
#   'themselves',
#   'will',
#   'i',
#   'just',
#   'elizabeth',
#   'they',
#   'shortly',
#   'stopping',
#   'elizabeth',
#   'to',
#   'it',
#   'he',
#   'feared',
#   'when',
#   'their',
#   'little',
#   'she',
#   'be',
#   'triumph',
#   'it',
#   'she',
#   'she',
#   'there',
#   'this',
#   'it',
#   'how',
#   'perhaps',
#   'said',
#   'to',
#   'he',
#   'stating',
#   'as',
#   'think',
#   'her',
#   'they',
#   'amongst',
#   'the',
#   'there',
#   'had',
#   'that',
#   'though',
#   'there',
#   'whenever',
#   'to',
#   'elizabeth',
#   'she',
#   'nothing',
#   'pride',
#   'above',
#   'for',
#   'gratitude',
#   'attended',
#   'she',
#   'this',
#   'a',
#   'perhaps',
#   'elizabeth',
#   'exerting',
#   'she',
#   'georgiana',
#   'not',
#   'angry',
#   'afterwards',
#   'that',
#   'herself',
#   'himself',
#   'on',
#   'the',
#   'i',
#   'i',
#   'this',
#   'were',
#   'i',
#   'though',
#   'i',
#   'too',
#   'no',
#   'without',
#   'no',
#   'i',
#   'this',
#   'as',
#   'now',
#   'circumstances',
#   'his',
#   'as',
#   'i',
#   'let',
#   'her',
#   'explained',
#   'it',
#   'is',
#   'not',
#   'nothing',
#   'i',
#   'the',
#   'self',
#   'real',
#   'i',
#   'if',
#   'jane',
#   'now',
#   'she',
#   'never',
#   'satisfying',
#   'be',
#   'all',
#   'what',
#   'wishes',
#   'she',
#   'to',
#   'of',
#   'i',
#   'their',
#   'why',
#   'as',
#   'can',
#   'love',
#   'really',
#   'she',
#   'amusement',
#   'love',
#   'you',
#   'jane',
#   'his',
#   'does',
#   'so',
#   'he',
#   'now',
#   'you',
#   'the',
#   'poor',
#   'i',
#   'tell',
#   'mr',
#   'we',
#   'was',
#   'certain',
#   'tell',
#   'nothing',
#   'when',
#   'not',
#   'i',
#   'to',
#   'one',
#   'i',
#   'at',
#   'to',
#   'the',
#   'i',
#   'under',
#   'he',
#   'the',
#   'at',
#   'even',
#   'three',
#   'without',
#   'as',
#   'on',
#   'it',
#   'the',
#   'before',
#   'likewise',
#   'since',
#   'his',
#   'myself',
#   'instead',
#   'i',
#   'perhaps',
#   'if',
#   'it',
#   'it',
#   'the',
#   'there',
#   'the',
#   'her',
#   'the',
#   'that',
#   'yet',
#   'it',
#   'in',
#   'was',
#   'there',
#   'a',
#   'on',
#   'ashworth',
#   'when',
#   'mr',
#   'at',
#   'while',
#   'no',
#   'how',
#   'mrs',
#   'jane',
#   'his',
#   'she',
#   'the',
#   'a',
#   'she',
#   'my',
#   'i',
#   'mrs',
#   'i',
#   'however',
#   'luckily',
#   'gracious',
#   'to',
#   'she',
#   'the',
#   'if',
#   'he',
#   'it',
#   'he',
#   'he',
#   'he',
#   'at',
#   'mr',
#   'would',
#   'our',
#   'this',
#   'at',
#   'lizzy',
#   'in',
#   'it',
#   'i',
#   'then',
#   'a',
#   'slyness',
#   'i',
#   'it',
#   'he',
#   'she',
#   'it',
#   'it',
#   'of',
#   'he',
#   'to',
#   'it',
#   'you',
#   'only',
#   'the',
#   'however',
#   'that',
#   'now',
#   "don't",
#   'i',
#   'she',
#   'it',
#   'however',
#   'i',
#   'she',
#   'it',
#   'on',
#   'elizabeth',
#   'else',
#   'little',
#   'elizabeth',
#   'to',
#   'she',
#   'more',
#   'perhaps',
#   'not',
#   'it',
#   'now',
#   'the',
#   'himself',
#   'could',
#   'however',
#   'at',
#   'little',
#   'every',
#   'her',
#   'though',
#   'jane',
#   'she',
#   'alas',
#   'if',
#   'that',
#   'their',
#   'why',
#   'was',
#   'with',
#   'i',
#   'when',
#   'unable',
#   'remained',
#   'elizabeth',
#   'on',
#   'hers',
#   'poorly',
#   'she',
#   'myself',
#   'as',
#   'little',
#   'she',
#   'how',
#   'when',
#   'a',
#   'it',
#   'see',
#   'such',
#   'their',
#   'one',
#   'i',
#   'no',
#   'lady',
#   'however',
#   'that',
#   'your',
#   'you',
#   'what',
#   'the',
#   'it',
#   'it',
#   'who',
#   'say',
#   'do',
#   'would',
#   'you',
#   'depend',
#   'from',
#   'it',
#   'they',
#   'i',
#   'now',
#   'to',
#   'could',
#   'never',
#   'lizzy',
#   'to',
#   'it',
#   'his',
#   'wonder',
#   'the',
#   'your',
#   'one',
#   'though',
#   'unluckily',
#   'since',
#   'it',
#   'though',
#   'i',
#   'it',
#   'think',
#   'what',
#   'with',
#   'i',
#   'left',
#   'for',
#   'most',
#   'not',
#   'my',
#   'my',
#   'surprise',
#   'i',
#   'it',
#   'his',
#   'his',
#   'she',
#   'neither',
#   'jane',
#   'the',
#   'in',
#   'are',
#   'are',
#   'we',
#   'i',
#   'his',
#   'now',
#   'lizzy',
#   'now',
#   'he',
#   'i',
#   'i',
#   'whether',
#   'he',
#   'they',
#   'will',
#   'this',
#   'let',
#   'had',
#   'these',
#   'the',
#   'before',
#   'my',
#   'the',
#   'i',
#   'what',
#   'in',
#   'nobody',
#   'make',
#   'i',
#   'i',
#   'tell',
#   'it',
#   'i',
#   'now',
#   'to',
#   'now',
#   'not',
#   'if',
#   'she',
#   'she',
#   'however',
#   'as',
#   ...],
#  'buy': ['pemberley', 'it', 'them', 'clothes'],
#  'bye': ['she', 'charles', 'mrs', 'give', 'you'],
#  'can': ['it',
#   'you',
#   'you',
#   'you',
#   'you',
#   'be',
#   'tell',
#   'but',
#   'you',
#   'assure',
#   'his',
#   'guess',
#   'all',
#   'perceive',
#   'command',
#   'answer',
#   'dance',
#   'avoid',
#   'have',
#   'guess',
#   'bestow',
#   'collect',
#   'never',
#   'on',
#   'i',
#   'get',
#   'you',
#   'add',
#   'have',
#   'be',
#   'in',
#   'be',
#   'do',
#   'you',
#   'write',
#   'be',
#   'compass',
#   'admire',
#   'all',
#   'be',
#   'but',
#   'overcome',
#   'clear',
#   'do',
#   'mean',
#   'he',
#   'assure',
#   'be',
#   'never',
#   'recall',
#   'forget',
#   'never',
#   'have',
#   'have',
#   'hardly',
#   'such',
#   'mr',
#   'they',
#   'please',
#   'be',
#   'form',
#   'his',
#   'much',
#   'have',
#   'have',
#   'give',
#   'at',
#   'readily',
#   'assure',
#   'it',
#   'be',
#   'have',
#   'have',
#   'hardly',
#   'bring',
#   'describe',
#   'assure',
#   'appear',
#   'offer',
#   'i',
#   'have',
#   'have',
#   'tell',
#   'there',
#   'for',
#   'doubt',
#   'hope',
#   'i',
#   'you',
#   'express',
#   'boast',
#   'you',
#   'be',
#   'have',
#   'be',
#   'you',
#   'only',
#   'secure',
#   'get',
#   'prevent',
#   'i',
#   'promise',
#   'safely',
#   'be',
#   'give',
#   'hardly',
#   'bear',
#   'ever',
#   'answer',
#   'think',
#   'be',
#   'know',
#   'afford',
#   'have',
#   'excuse',
#   'you',
#   'you',
#   'you',
#   'you',
#   'help',
#   'treat',
#   'only',
#   'only',
#   'summon',
#   'tell',
#   'appeal',
#   'be',
#   'daughters',
#   'boast',
#   'from',
#   'make',
#   'be',
#   'be',
#   'you',
#   'never',
#   'you',
#   'never',
#   'tell',
#   'be',
#   'this',
#   'give',
#   'it',
#   'now',
#   'easily',
#   'give',
#   'throw',
#   'i',
#   'tempt',
#   'be',
#   'be',
#   'be',
#   'you',
#   'believe',
#   'you',
#   'captivate',
#   'she',
#   'remember',
#   'get',
#   'hardly',
#   'remove',
#   'alleviate',
#   'they',
#   'or',
#   'prove',
#   'i',
#   'and',
#   'it',
#   'never',
#   'ever',
#   'call',
#   'i',
#   'collect',
#   'be',
#   'give',
#   'be',
#   'but',
#   'hardly',
#   'know',
#   'it',
#   'afford',
#   'teach',
#   'you',
#   'said',
#   'never',
#   'have',
#   'be',
#   'you',
#   'never',
#   'have',
#   'be',
#   'be',
#   'now',
#   'he',
#   'you',
#   'most',
#   'no',
#   'be',
#   'scarcely',
#   'easily',
#   'remember',
#   'hardly',
#   'you',
#   'it',
#   'be',
#   'be',
#   'be',
#   'he',
#   'think',
#   'comprehend',
#   'spare',
#   'but',
#   'copy',
#   'do',
#   'do',
#   'easily',
#   'do',
#   'be',
#   'receive',
#   'help',
#   'be',
#   'be'],
#  'cry': ['well'],
#  'cup': ['himself'],
#  'day': ['have',
#   'before',
#   'but',
#   'and',
#   'before',
#   'then',
#   'added',
#   'as',
#   'with',
#   'said',
#   'her',
#   'in',
#   'of',
#   'passed',
#   'before',
#   'you',
#   'or',
#   'much',
#   'but',
#   'to',
#   'must',
#   'because',
#   'lydia',
#   'i',
#   'has',
#   'before',
#   'before',
#   'and',
#   'at',
#   'before',
#   'what',
#   'of',
#   'of',
#   'before',
#   'we',
#   'for',
#   'opened',
#   'you',
#   'with',
#   'i',
#   'to',
#   'was',
#   'that',
#   'before',
#   'or',
#   'nothing',
#   'wear',
#   'for',
#   'after',
#   'passed',
#   'was',
#   'or',
#   'confirms',
#   'seldom',
#   'mrs',
#   'your',
#   'would',
#   'without',
#   'that',
#   'said',
#   'and',
#   'were',
#   'passed',
#   'as',
#   'chapter',
#   'or',
#   'altogether',
#   'do',
#   'that',
#   'she',
#   'almost',
#   'and',
#   'before',
#   'they',
#   'as',
#   'after',
#   'was',
#   'following',
#   'or',
#   'went',
#   'or',
#   'at',
#   'there',
#   'before',
#   'she',
#   'what',
#   'but',
#   'of',
#   'of',
#   'his',
#   'unless',
#   'her',
#   'long',
#   'before',
#   'and',
#   'were',
#   'after',
#   'opened',
#   'when',
#   'after',
#   'of',
#   'before',
#   'later',
#   'later',
#   'before',
#   'oh',
#   'of',
#   'it',
#   'and',
#   'and',
#   'i',
#   'at',
#   'of',
#   'was',
#   'which',
#   'i',
#   'in',
#   'i',
#   'she',
#   'arrived',
#   'i',
#   'but',
#   'of',
#   'after',
#   'it',
#   'and',
#   'of',
#   'or',
#   'lizzy',
#   'of',
#   'but',
#   'i',
#   'to',
#   'said',
#   'were',
#   'jane',
#   'i',
#   'but',
#   'i',
#   'on'],
#  'did': ['not',
#   'not',
#   'not',
#   'not',
#   'for',
#   'not',
#   'look',
#   'not',
#   'seem',
#   'i',
#   'not',
#   'not',
#   'admire',
#   'you',
#   'not',
#   'sir',
#   'when',
#   'not',
#   'at',
#   'not',
#   'indeed',
#   'the',
#   'not',
#   'charlotte',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'himself',
#   'by',
#   'finish',
#   'not',
#   'not',
#   'not',
#   'the',
#   'she',
#   'before',
#   'not',
#   'not',
#   'not',
#   'not',
#   'approach',
#   'not',
#   'you',
#   'not',
#   'not',
#   'done',
#   'not',
#   'not',
#   'whether',
#   'not',
#   'it',
#   'she',
#   'not',
#   'before',
#   'elizabeth',
#   'she',
#   'she',
#   'she',
#   'the',
#   'mrs',
#   'mr',
#   'not',
#   'not',
#   'injustice',
#   'not',
#   'that',
#   'experience',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'the',
#   'not',
#   'not',
#   'at',
#   'not',
#   'i',
#   'come',
#   'i',
#   'not',
#   'january',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'nothing',
#   'without',
#   'not',
#   'i',
#   'not',
#   'not',
#   'not',
#   'for',
#   'not',
#   'not',
#   'not',
#   'not',
#   'he',
#   'not',
#   'a',
#   'and',
#   'she',
#   'not',
#   'speak',
#   'not',
#   'elizabeth',
#   'and',
#   'she',
#   'not',
#   'turn',
#   'mr',
#   'he',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'everything',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'she',
#   'not',
#   'everything',
#   'not',
#   'not',
#   'not',
#   'we',
#   'not',
#   'mrs',
#   'lydia',
#   'mr',
#   'but',
#   'she',
#   'she',
#   'elizabeth',
#   'you',
#   'not',
#   'not',
#   'weep',
#   'not',
#   'pass',
#   'at',
#   'he',
#   'she',
#   'he',
#   'it',
#   'give',
#   'elizabeth',
#   'she',
#   'catch',
#   'not',
#   'much',
#   'not',
#   'her',
#   'venture',
#   'not',
#   'he',
#   'not',
#   'not',
#   'trace',
#   'not',
#   'she',
#   'the',
#   'not',
#   'colonel',
#   'own',
#   'he',
#   'not',
#   'colonel',
#   'not',
#   'he',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'she',
#   'not',
#   'think',
#   'not',
#   'every',
#   'not',
#   'not',
#   'not',
#   'i',
#   'not',
#   'not',
#   'not',
#   'know',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'whisper',
#   'she',
#   'not',
#   'and',
#   'she',
#   'you',
#   'you',
#   'i',
#   'you',
#   'hear',
#   'and',
#   'not',
#   'as',
#   'not',
#   'a',
#   'he',
#   'say',
#   'you',
#   'and',
#   'not',
#   'not',
#   'not',
#   'he',
#   'not',
#   'her',
#   'not',
#   'indeed',
#   'she',
#   'not',
#   'he',
#   'not',
#   'as',
#   'not',
#   'not',
#   'not',
#   'she',
#   'not',
#   'call',
#   'you',
#   'not',
#   'the',
#   'it',
#   'it',
#   'you',
#   'not',
#   'not',
#   'you',
#   'bingley',
#   'not',
#   'you',
#   'not',
#   'she',
#   'conquer',
#   'every',
#   'you',
#   'you',
#   'you',
#   'not',
#   'you',
#   'but',
#   'in',
#   'shrug',
#   'speak',
#   'all'],
#  'die': ['it', 'of', 'of', 'of'],
#  'due': ['form',
#   'the',
#   'time',
#   'to',
#   'consideration',
#   'to',
#   'than',
#   'to',
#   'but',
#   'to',
#   'my'],
#  'ear': ['i'],
#  'eat': ['up', 'drink', 'and', 'drink', 'and'],
#  'edw': ['gardiner'],
#  'ein': ['or'],
#  'end': ['of',
#   'of',
#   'of',
#   'of',
#   'without',
#   'elizabeth',
#   'by',
#   'to',
#   'of',
#   'of',
#   'and',
#   'to',
#   'and',
#   'to',
#   'in',
#   'on',
#   'to',
#   'to',
#   'well',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'in',
#   'so',
#   'of',
#   'to',
#   'but',
#   'of',
#   'of'],
#  'ere': ['long', 'they'],
#  'err': ['but', 'and', 'you'],
#  'esq': ['to'],
#  'etc': ['mrs',
#   'well',
#   'this',
#   'are',
#   'etc',
#   'mr',
#   'edw',
#   'e',
#   'etc',
#   'and',
#   'mr',
#   'miss',
#   'as'],
#  'eye': ['he',
#   'more',
#   'and',
#   'was',
#   'at',
#   'was',
#   'on',
#   'of',
#   'was',
#   'power',
#   'of',
#   'which',
#   'she',
#   'mr',
#   'she'],
#  'far': ['from',
#   'differ',
#   'as',
#   'alone',
#   'from',
#   'from',
#   'superior',
#   'beyond',
#   'netherfield',
#   'beyond',
#   'from',
#   'from',
#   'from',
#   'from',
#   'from',
#   'be',
#   'from',
#   'from',
#   'from',
#   'resigned',
#   'it',
#   'from',
#   'awakened',
#   'as',
#   'and',
#   'as',
#   'recommended',
#   'as',
#   'each',
#   'as',
#   'from',
#   'as',
#   'be',
#   'as',
#   'from',
#   'and',
#   'as',
#   'and',
#   'from',
#   'as',
#   'she',
#   'it',
#   'enough',
#   'as',
#   'off',
#   'from',
#   'as',
#   'as',
#   'off',
#   'from',
#   'beyond',
#   'too',
#   'what',
#   'we',
#   'your',
#   'from',
#   'from',
#   'as'],
#  'fat': ['a'],
#  'fee': ['for', 'as', 'or', 'for', 'for', 'of', 'is', 'or'],
#  'few': ['lines',
#   'days',
#   'minutes',
#   'of',
#   'of',
#   'books',
#   'subjects',
#   'neighbourhoods',
#   'hints',
#   'moments',
#   'moments',
#   'of',
#   'minutes',
#   'moments',
#   'words',
#   'people',
#   'weeks',
#   'days',
#   'lines',
#   'struggles',
#   'minutes',
#   'minutes',
#   'days',
#   'as',
#   'weeks',
#   'people',
#   'minutes',
#   'sensible',
#   'minutes',
#   'formal',
#   'moments',
#   'weeks',
#   'moments',
#   'minutes',
#   'minutes',
#   'domestics',
#   'can',
#   'short',
#   'minutes',
#   'days',
#   'minutes',
#   'days',
#   'petrified',
#   'people',
#   'minutes',
#   'moments',
#   'moments',
#   'hours',
#   'minutes',
#   'months',
#   'moments',
#   'lines',
#   'minutes',
#   'lines',
#   'minutes',
#   'days',
#   'days',
#   'presents',
#   'people',
#   'weeks',
#   'days',
#   'moments',
#   'days',
#   'minutes',
#   'words',
#   'minutes',
#   'balls',
#   'weeks',
#   'days',
#   'minutes',
#   'days',
#   'things'],
#  'fit': ['of', 'to', 'to', 'to'],
#  'fix': ['his', 'the', 'on', 'the'],
#  'for': ['the',
#   'mrs',
#   'our',
#   'that',
#   'as',
#   'i',
#   'one',
#   'in',
#   'it',
#   'us',
#   'my',
#   'my',
#   'your',
#   "heaven's",
#   'my',
#   'her',
#   'she',
#   'you',
#   'his',
#   'that',
#   'your',
#   'though',
#   'in',
#   'they',
#   'the',
#   'about',
#   'he',
#   'themselves',
#   'two',
#   'her',
#   'a',
#   'a',
#   'a',
#   'you',
#   'she',
#   'at',
#   'the',
#   'me',
#   "god's",
#   'he',
#   'you',
#   'that',
#   'his',
#   'half',
#   'none',
#   'though',
#   'he',
#   'half',
#   'it',
#   'him',
#   'him',
#   'many',
#   'falling',
#   'a',
#   'knowledge',
#   'display',
#   'young',
#   'i',
#   'a',
#   'one',
#   'who',
#   'his',
#   'her',
#   'the',
#   'the',
#   'miss',
#   'an',
#   'the',
#   'a',
#   'her',
#   'elizabeth',
#   'the',
#   'it',
#   'such',
#   'the',
#   'jane',
#   'the',
#   'a',
#   'the',
#   'jane',
#   'mr',
#   'her',
#   'miss',
#   'some',
#   'the',
#   'your',
#   'a',
#   'her',
#   'her',
#   'the',
#   'captivation',
#   'immediately',
#   'one',
#   'early',
#   'such',
#   'she',
#   'she',
#   'a',
#   'such',
#   'ever',
#   'a',
#   'my',
#   'her',
#   'elizabeth',
#   'the',
#   'my',
#   'themselves',
#   'his',
#   'troubling',
#   'you',
#   'a',
#   'me',
#   'a',
#   'words',
#   'you',
#   'he',
#   'by',
#   'himself',
#   'opinions',
#   'the',
#   'the',
#   'arguments',
#   'complying',
#   'that',
#   'talking',
#   'an',
#   'his',
#   'her',
#   'the',
#   'the',
#   'my',
#   'your',
#   'what',
#   'our',
#   'a',
#   "bingley's",
#   'cards',
#   'some',
#   'the',
#   'their',
#   'such',
#   'it',
#   'anyone',
#   'it',
#   'the',
#   'it',
#   'them',
#   'she',
#   'her',
#   'the',
#   'her',
#   'half',
#   'jane',
#   'them',
#   'her',
#   'i',
#   'some',
#   'me',
#   'having',
#   'it',
#   'lady',
#   'being',
#   'their',
#   'else',
#   'such',
#   'the',
#   'having',
#   'about',
#   'his',
#   'him',
#   'a',
#   'you',
#   'everything',
#   'their',
#   'certainly',
#   "lydia's",
#   'backgammon',
#   'her',
#   'her',
#   'inheriting',
#   'the',
#   'in',
#   'it',
#   'thither',
#   'a',
#   'the',
#   'his',
#   'she',
#   'the',
#   'a',
#   'an',
#   'the',
#   'in',
#   'his',
#   'his',
#   'she',
#   'anyone',
#   'the',
#   'i',
#   'me',
#   'me',
#   'avoiding',
#   'but',
#   'the',
#   'me',
#   'such',
#   'your',
#   'me',
#   'dishonesty',
#   'almost',
#   'he',
#   'fortune',
#   'a',
#   'his',
#   'another',
#   'many',
#   'her',
#   'her',
#   'neither',
#   'us',
#   'it',
#   'his',
#   'the',
#   'the',
#   'though',
#   'it',
#   'everybody',
#   'the',
#   'her',
#   'those',
#   'it',
#   'and',
#   'from',
#   'netherfield',
#   'mr',
#   'the',
#   'mr',
#   "wickham's",
#   'ill',
#   'the',
#   'a',
#   'a',
#   'her',
#   'wickham',
#   'some',
#   'the',
#   'half',
#   'the',
#   'i',
#   'her',
#   'detaining',
#   'themselves',
# ...
#   'mr',
#   'and',
#   'of',
#   'this',
#   'to',
#   'as',
#   'you',
#   'his',
#   'but',
#   'you',
#   'to',
#   'but',
#   'to',
#   'than',
#   'only',
#   'for',
#   'to',
#   'to',
#   'of',
#   'said',
#   'of',
#   'through',
#   'at',
#   'to',
#   'i',
#   'the',
#   'was',
#   'and',
#   'you',
#   'but',
#   'i',
#   'very',
#   'as',
#   'a',
#   'than',
#   'that',
#   'and',
#   'along',
#   'of',
#   'to',
#   'to',
#   'of',
#   'that',
#   'of',
#   'home',
#   'to',
#   'below',
#   'if',
#   'home',
#   'teaching',
#   'with',
#   'as',
#   'again',
#   'towards',
#   'the',
#   'by',
#   'to',
#   'of',
#   'after',
#   'and',
#   'and',
#   'horrible',
#   'since',
#   'and',
#   'to',
#   'towards',
#   'of',
#   'off',
#   'of',
#   'to',
#   'from',
#   'that',
#   'to',
#   'through',
#   'if',
#   'with',
#   'i',
#   'that',
#   'elizabeth',
#   'again',
#   'i',
#   'by',
#   'to',
#   'either',
#   'with',
#   'with'],
#  'web': ['site', 'page', 'site', 'pages', 'site', 'site'],
#  'wet': ['through', 'night'],
#  'who': ['has',
#   'waited',
#   'came',
#   'is',
#   'are',
#   'she',
#   'had',
#   'had',
#   'best',
#   'had',
#   'piqued',
#   'do',
#   'came',
#   'have',
#   'made',
#   'had',
#   'must',
#   'having',
#   'with',
#   'though',
#   'would',
#   'had',
#   'were',
#   'is',
#   'had',
#   'lived',
#   'when',
#   'lives',
#   'delighted',
#   'cannot',
#   'deserves',
#   'does',
#   'answered',
#   'seek',
#   'waited',
#   'arrived',
#   'fancied',
#   'fancy',
#   'first',
#   'continued',
#   'can',
#   'is',
#   'had',
#   'had',
#   'do',
#   'when',
#   'quarreled',
#   'assured',
#   'superintended',
#   'still',
#   'was',
#   'he',
#   'had',
#   'had',
#   'introduced',
#   'in',
#   'was',
#   'was',
#   'could',
#   'had',
#   'followed',
#   'had',
#   'seems',
#   'are',
#   'could',
#   'chooses',
#   'have',
#   'had',
#   'could',
#   'consider',
#   'told',
#   'took',
#   'were',
#   'had',
#   'never',
#   'had',
#   'does',
#   'would',
#   'sat',
#   'had',
#   'continued',
#   'should',
#   'continued',
#   'often',
#   'was',
#   'however',
#   'are',
#   'could',
#   'naturally',
#   'had',
#   'flying',
#   'came',
#   'is',
#   'suffer',
#   'do',
#   'entered',
#   'has',
#   'has',
#   'accepted',
#   'could',
#   'married',
#   'has',
#   'will',
#   'could',
#   'came',
#   'lived',
#   'was',
#   'think',
#   'would',
#   'when',
#   'was',
#   'has',
#   'live',
#   'live',
#   'has',
#   'has',
#   'breathless',
#   'lives',
#   'would',
#   'could',
#   'could',
#   'had',
#   'was',
#   'was',
#   'she',
#   'taught',
#   'attended',
#   'chose',
#   'was',
#   'had',
#   'talked',
#   'led',
#   'have',
#   'has',
#   'called',
#   'would',
#   'lived',
#   'seems',
#   'can',
#   'was',
#   'was',
#   'though',
#   'had',
#   'was',
#   'has',
#   'that',
#   'advanced',
#   'had',
#   'had',
#   'had',
#   'was',
#   'had',
#   'is',
#   'presided',
#   'left',
#   'from',
#   'on',
#   'have',
#   'have',
#   'have',
#   'thinks',
#   'have',
#   'could',
#   'sat',
#   'would',
#   'would',
#   'will',
#   'is',
#   'could',
#   'have',
#   'might',
#   'so',
#   'shed',
#   'had',
#   'was',
#   'had',
#   'is',
#   'are',
#   'think',
#   'had',
#   'met',
#   'astonished',
#   'was',
#   'they',
#   'was',
#   'fatigued',
#   'will',
#   'more',
#   'showed',
#   'had',
#   'had',
#   'was',
#   'had',
#   'she',
#   'was',
#   'felt',
#   'with',
#   'could',
#   'had',
#   'instantly',
#   'knew',
#   'in',
#   'is',
#   'was',
#   'is',
#   'had',
#   'treated',
#   'came',
#   'attended',
#   'had',
#   'i',
#   'did',
#   'considered',
#   'but',
#   'believed',
#   'would',
#   'knew',
#   'as',
#   'could',
#   'is',
#   'was',
#   'should',
#   'came',
#   'took',
#   'said',
#   'was',
#   'was',
#   'should',
#   'were',
#   'in',
#   'were',
#   'are',
#   'agreed',
#   'gave',
#   'followed',
#   'caused',
#   'happened',
#   'never',
#   'was',
#   'were',
#   'had',
#   'could',
#   'was',
#   'knows',
#   'can',
#   'knew',
#   'knew',
#   'had',
#   'joined',
#   'were',
#   'has',
#   'would',
#   'had',
#   'as',
#   'had',
#   'was',
#   'could',
#   'preceded',
#   'i',
#   'was',
#   'i',
#   'was',
#   'are',
#   'their',
#   'came',
#   'is',
#   'this',
#   'never',
#   'probably',
#   'wanted',
#   'did',
#   'wrote',
#   'received',
#   'though',
#   'would',
#   'were',
#   'so',
#   'could',
#   'had',
#   'must',
#   'might',
#   'remained',
#   'had',
#   'by',
#   'agree',
#   'notifies',
#   'approach'],
#  'why': ['my',
#   'did',
#   'are',
#   'must',
#   'could',
#   'indeed',
#   'did',
#   'my',
#   'will',
#   'should',
#   'should',
#   'should',
#   'should',
#   'should',
#   'does',
#   'did',
#   'a',
#   'mr',
#   'she',
#   'she',
#   'was',
#   'upon',
#   'with',
#   'with',
#   'all',
#   'at',
#   'mrs',
#   'did',
#   'did',
#   'is',
#   'should',
#   'all',
#   'any',
#   'must',
#   'did',
#   'without',
#   'he',
#   'all',
#   'did',
#   'if',
#   'not',
#   'come',
#   'silent',
#   'should',
#   'is',
#   'he',
#   'am',
#   'i',
#   'is',
#   'may',
#   'lady',
#   'i',
#   'especially'],
#  'win': ['him'],
#  'wit': ['flowed', 'and', 'and', 'to', 'but', 'been'],
#  'woe': ['how'],
#  'won': ['and', 'in', 'and', 'too'],
#  'yes': ['but',
#   'these',
#   'indeed',
#   'but',
#   'and',
#   'and',
#   'all',
#   'i',
#   'i',
#   'but',
#   'indeed',
#   'she',
#   'but',
#   'it',
#   'that',
#   'do',
#   'vanity',
#   'replied',
#   'the',
#   'it',
#   'always',
#   'certainly',
#   'or',
#   'there',
#   'to',
#   'in',
#   'of',
#   'and',
#   'miss',
#   'she',
#   "ma'am",
#   'my',
#   'indeed',
#   'i',
#   'if',
#   'said',
#   'i',
#   'his',
#   'thought',
#   'yes',
#   'they',
#   'if',
#   'almost',
#   'very',
#   'very',
#   'the',
#   'sir',
#   'sir',
#   "ma'am",
#   'replied',
#   'they',
#   'be',
#   'and',
#   'that',
#   'he',
#   'but',
#   'where',
#   'i',
#   'yes',
#   'they',
#   'there',
#   'he',
#   'she',
#   'he',
#   'there',
#   'very',
#   'she',
#   'he',
#   'madam',
#   'very',
#   'and',
#   'miss',
#   'pray',
#   'that',
#   'you',
#   'you'],
#  'yet': ['learnt',
#   'she',
#   'the',
#   'the',
#   'add',
#   'what',
#   'upon',
#   'that',
#   'taught',
#   'i',
#   'he',
#   'seen',
#   'it',
#   'returned',
#   'for',
#   'however',
#   'greater',
#   'whether',
#   'in',
#   'more',
#   'if',
#   'it',
#   'open',
#   'it',
#   'you',
#   'she',
#   'recover',
#   'ignorant',
#   'learnt',
#   'more',
#   'he',
#   'how',
#   'merited',
#   'heavier',
#   'expressed',
#   'lost',
#   'how',
#   'been',
#   'despaired',
#   'i',
#   'more',
#   'there',
#   'visited',
#   'time',
#   'a',
#   'made',
#   'elizabeth',
#   'more',
#   'he',
#   'replied',
#   'leave',
#   'deserted',
#   'he',
#   'be',
#   'the',
#   'so',
#   'there',
#   'i',
#   'it',
#   'had',
#   'she',
#   'why',
#   'the',
#   'received',
#   'in',
#   'to',
#   'indeed',
#   'now',
#   'was',
#   'answered',
#   'whenever',
#   'be',
#   'for'],
#  'you': ['may',
#   'heard',
#   'not',
#   'want',
#   'must',
#   'be',
#   'must',
#   'talk',
#   'must',
#   'and',
#   'may',
#   'are',
#   'the',
#   'flatter',
#   'must',
#   'but',
#   'know',
#   'must',
#   'do',
#   'are',
#   'and',
#   'to',
#   'will',
#   'are',
#   'abuse',
#   'take',
#   'have',
#   'mistake',
#   'mention',
#   'do',
#   'will',
#   'will',
#   'forget',
#   'do',
#   'mrs',
#   'tear',
#   'may',
#   'be',
#   'decline',
#   'consider',
#   'there',
#   'mary',
#   'are',
#   'tell',
#   'my',
#   'at',
#   'loved',
#   'should',
#   'may',
#   'choose',
#   'have',
#   'will',
#   'to',
#   'are',
#   'at',
#   'dance',
#   'standing',
#   'had',
#   'know',
#   'are',
#   'see',
#   'are',
#   'who',
#   'which',
#   'mean',
#   'had',
#   'are',
#   'had',
#   'know',
#   'she',
#   'had',
#   'i',
#   'but',
#   'by',
#   'again',
#   'were',
#   'leave',
#   'have',
#   'are',
#   'know',
#   'never',
#   'speak',
#   'do',
#   'alone',
#   'like',
#   'their',
#   'converse',
#   'began',
#   'were',
#   'mean',
#   'mean',
#   'mr',
#   'know',
#   'would',
#   'quite',
#   'i',
#   'never',
#   'would',
#   'ought',
#   'at',
#   'do',
#   'represent',
#   'must',
#   'are',
#   'make',
#   'know',
#   'would',
#   'not',
#   'are',
#   'know',
#   'are',
#   'would',
#   'are',
#   'saw',
#   'often',
#   'not',
#   'have',
#   'not',
#   'must',
#   'as',
#   'cannot',
#   'and',
#   'not',
#   'excel',
#   'and',
#   'are',
#   'my',
#   'joy',
#   'to',
#   'would',
#   'are',
#   'will',
#   'he',
#   'must',
#   'should',
#   'as',
#   'must',
#   'are',
#   'can',
#   'had',
#   'must',
#   'were',
#   'have',
#   'should',
#   'be',
#   'will',
#   'get',
#   'said',
#   'saw',
#   'observed',
#   'would',
#   'say',
#   'prefer',
#   'have',
#   'have',
#   'have',
#   'are',
#   'neglect',
#   'build',
#   'to',
#   'mean',
#   'in',
#   'must',
#   'so',
#   'describe',
#   'may',
#   'have',
#   'will',
#   'have',
#   'said',
#   'begin',
#   'cried',
#   'perfectly',
#   'are',
#   'are',
#   'were',
#   'move',
#   'there',
#   'have',
#   'are',
#   'quite',
#   'must',
#   'no',
#   'it',
#   'must',
#   'to',
#   'shall',
#   'please',
#   'would',
#   'have',
#   'write',
#   'are',
#   'must',
#   'do',
#   'i',
#   'but',
#   'contrive',
#   'give',
#   'always',
#   'darcy',
#   'call',
#   'are',
#   'consider',
#   'think',
#   'told',
#   'ever',
#   'should',
#   'meant',
#   'believed',
#   'would',
#   'were',
#   'had',
#   'would',
#   'would',
#   'have',
#   'have',
#   'are',
#   'expect',
#   'choose',
#   'must',
#   'to',
#   'appear',
#   'have',
#   'think',
#   'may',
#   'that',
#   'dislike',
#   'and',
#   'may',
#   'like',
#   'ask',
#   'feel',
#   'before',
#   'wanted',
#   'might',
#   'that',
#   'dare',
#   'will',
#   'can',
#   'anything',
#   'know',
#   'must',
#   'intended',
#   'used',
#   'were',
#   'are',
#   'are',
#   'really',
#   'before',
#   'determine',
#   'mean',
#   'to',
#   'it',
#   'either',
#   'are',
#   'are',
#   'much',
#   'have',
#   'are',
#   'must',
#   'that',
#   'please',
#   'are',
#   'have',
#   'are',
#   'will',
#   'have',
#   'mean',
#   'all',
#   'i',
#   'will',
#   'may',
#   'at',
#   'as',
#   'will',
#   'to',
#   'of',
#   'should',
#   'and',
#   'are',
#   'allude',
#   'must',
#   'for',
#   'sir',
#   'said',
#   'may',
#   'judge',
#   'that',
#   'possess',
#   'know',
#   'could',
#   'certain',
#   'may',
#   'probably',
#   'much',
#   'would',
#   'are',
#   'will',
#   'not',
#   'whose',
#   'said',
#   'if',
#   'will',
#   'know',
#   'know',
#   'got',
#   'choose',
#   'will',
#   'said',
#   'will',
#   'ought',
#   'talk',
#   'are',
#   'know',
#   'consulting',
#   'imagine',
#   'are',
#   'think',
#   'met',
#   'belong',
#   'and',
#   'sir',
#   'will',
#   'from',
#   'of',
#   'think',
#   'in',
#   'once',
#   'hardly',
#   'are',
#   'as',
#   'were',
#   'are',
#   'among',
#   'however',
#   'miss',
#   'accuse',
#   'he',
#   'are',
#   'expect',
#   'have',
#   'have',
#   'may',
#   'mr',
#   'must',
#   'are',
#   'must',
#   'said',
#   'to',
#   'will',
#   'have',
#   'up',
#   'will',
#   'to',
#   'are',
#   'any',
#   'would',
#   'that',
#   'can',
#   'to',
#   'out',
#   'must',
#   'must',
#   'can',
#   'will',
#   'there',
#   'in',
#   'may',
#   'may',
#   'are',
#   'forget',
#   'are',
#   'have',
#   'to',
#   'that',
#   'could',
#   'so',
#   'and',
#   'may',
#   'must',
#   'very',
#   'must',
#   'next',
#   'have',
#   'of',
#   'have',
#   'puzzle',
#   'in',
#   'of',
#   'must',
#   'should',
#   'your',
#   'are',
#   'sir',
#   'again',
#   'have',
#   'but',
#   'are',
#   'madam',
#   'quite',
#   'are',
#   'must',
#   'do',
#   'said',
#   'talking',
#   'insist',
#   'on',
#   'an',
#   'have',
#   'elizabeth',
#   'must',
#   'again',
#   'do',
#   'again',
#   'do',
#   'mean',
#   'promised',
#   'will',
#   'are',
#   'think',
#   'miss',
#   'take',
#   'will',
#   'when',
#   'and',
#   'i',
#   'from',
#   'in',
#   'know',
#   'again',
#   'will',
#   'all',
#   'hold',
#   'will',
#   'to',
#   'shall',
#   'for',
#   'should',
#   'have',
#   'when',
#   'my',
#   'it',
#   'think',
#   'do',
#   'the',
#   'mr',
#   'my',
#   'will',
#   'think',
#   'hear',
#   'shall',
#   'and',
#   'that',
#   'jane',
#   'ought',
#   'together',
#   'cannot',
#   'her',
#   'on',
#   'he',
#   'could',
#   'will',
#   'have',
#   'must',
#   'find',
#   'by',
#   'talk',
#   'must',
#   'would',
#   'than',
#   'may',
#   'had',
#   'for',
#   'may',
#   'cannot',
#   'find',
#   'will',
#   'be',
#   'think',
#   'but',
#   'are',
#   'must',
#   'but',
#   'have',
#   'will',
#   'know',
#   'tell',
#   'know',
#   'mind',
#   'are',
#   'doubt',
#   'have',
#   'are',
#   'i',
#   'justice',
#   'as',
#   'deserve',
#   'wish',
#   'perfect',
#   'set',
#   'need',
#   'do',
#   'i',
#   'know',
#   'must',
#   'shall',
#   'shall',
#   'will',
#   'alluded',
#   'mentioned',
#   'but',
#   'dear',
#   'impute',
#   'by',
#   'esteem',
#   'can',
#   'persist',
#   'are',
#   'make',
#   'will',
#   'creditably',
#   'sir',
#   'you',
#   'have',
#   'tell',
#   'describe',
#   'lizzy',
#   'would',
#   'think',
#   'well',
#   'think',
#   'are',
#   'are',
#   'be',
#   'could',
#   'must',
#   'you',
#   'have',
#   'to',
#   'must',
#   'to',
#   'need',
#   'are',
#   'unhappy',
#   'therefore',
#   'discourage',
#   'should',
#   'know',
#   'are',
#   'very',
#   'certainly',
#   'will',
#   'come',
#   'will',
#   'will',
#   'right',
#   'very',
#   'have',
#   'will',
#   'were',
#   'want',
#   'will',
#   'choose',
#   'know',
#   'give',
#   'will',
#   'will',
#   'will',
#   'and',
#   'what',
#   'merely',
#   'for',
#   'play',
#   'our',
#   'shall',
#   'all',
#   'ought',
#   'draw',
#   'not',
#   'had',
#   'to',
#   'we',
#   'who',
#   'without',
#   'must',
#   'of',
#   'have',
#   'only',
#   'give',
#   'cannot',
#   'need',
#   'eliza',
#   'never',
#   'are',
#   'are',
#   'telling',
#   'are',
#   'madam',
#   'know',
#   'mean',
#   'are',
#   'could',
#   'and',
#   'find',
#   'a',
#   'not',
#   'to',
#   'knew',
#   'said',
#   'have',
#   'shall',
#   'must',
#   'think',
#   'cannot',
#   'are',
#   'have',
#   'can',
#   'all',
#   'all',
#   'left',
#   'she',
#   'call',
#   'cannot',
#   'cannot',
#   'pleased',
#   'or',
#   'ever',
#   'going',
#   'certainly',
#   'know',
#   'ever',
#   'been',
#   'chose',
#   'had',
#   'would',
#   'down',
#   'indeed',
#   'make',
#   'much',
#   'need',
#   'say',
#   'know',
#   'mean',
#   'may',
#   'reasons',
#   'elizabeth',
#   'have',
#   'are',
#   'must',
#   'how',
#   "elizabeth's",
#   'but',
#   'have',
#   'tell',
#   'chose',
#   'liked',
#   'know',
#   'had',
#   'think',
#   'no',
#   'acted',
#   'dare',
#   'cannot',
#   'have',
#   'deny',
#   'have',
#   'was',
#   'have',
#   'here',
#   'here',
#   'take',
#   'have',
#   'have',
#   'must',
#   'have',
#   'have',
#   'can',
#   'hold',
#   'for',
#   'into',
#   'expect',
#   'are',
#   'suppose',
#   'had',
#   'behaved',
#   'could',
#   'your',
#   'a',
#   'were',
#   'have',
#   'will',
#   'do',
#   'i',
#   'or',
#   'must',
#   'last',
#   'i',
#   'have',
#   'but',
#   'consolation',
#   'and',
#   'i',
#   'very',
#   'the',
#   'pain',
#   'only',
#   'will',
#   'may',
#   'do',
#   'will',
#   'but',
#   'previously',
#   'may',
#   'last',
#   'cannot',
#   'fitzwilliam',
#   'i',
#   'must',
#   'may',
#   'will',
#   'to',
#   'came',
#   'for',
#   'if',
#   'will',
#   'as',
#   'and',
#   'both',
#   'are',
#   'large',
#   'are',
#   'must',
#   'know',
#   'must',
#   'must',
#   'to',
#   'have',
#   'change',
#   'mention',
#   'will',
#   'will',
#   'we',
#   'will',
#   'have',
#   'to',
#   'see',
#   'see',
#   'may',
#   'will',
#   'have',
#   'my',
#   'equal',
#   'will',
#   'while',
#   'have',
#   'all',
#   'must',
#   'said',
#   'think',
#   'thought',
#   'she',
#   'all',
#   'went',
#   'seen',
#   'had',
#   'would',
#   'came',
#   'so',
#   "can't",
#   'and',
#   'about',
#   'think',
#   'cannot',
#   'are',
#   'had',
#   'would',
#   'too',
#   'do',
#   'oh',
#   'blame',
#   'were',
#   'did',
#   'will',
#   'what',
#   'never',
#   'must',
#   'shall',
#   'choose',
#   'must',
#   'so',
#   'will',
#   'lament',
#   'used',
#   'first',
#   'could',
#   'do',
#   'how',
#   'should',
#   'are',
#   'be',
#   'were',
#   'would',
#   'are',
#   'my',
#   'suppose',
#   'and',
#   'must',
#   'will',
#   'say',
#   'saw',
#   'who',
#   'i',
#   'like',
#   'have',
#   'know',
#   'can',
#   'think',
#   'will',
#   'might',
#   'should',
#   'are',
#   'would',
#   'were',
#   'mr',
#   'will',
#   'allow',
#   'to',
#   'and',
#   'thought',
#   'be',
#   'will',
#   'have',
#   'and',
#   'have',
#   'i',
#   'all',
#   'i',
#   'a',
#   'are',
#   'cannot',
#   'could',
#   'present',
#   'one',
#   'are',
#   'she',
#   'know',
#   'have',
#   'with',
#   'at',
#   'sent',
#   'really',
#   'yourself',
#   'see',
#   'think',
#   'see',
#   'really',
#   'the',
#   'yourself',
#   'and',
#   'may',
#   'had',
#   'must',
#   'word',
#   'heard',
#   'all',
#   'all',
#   'how',
#   'cried',
#   'look',
#   'must',
#   'are',
#   'get',
#   'are',
#   'will',
#   'entertained',
#   'will',
#   'know',
#   'cannot',
#   'a',
#   'need',
#   'do',
#   'would',
#   'will',
#   'you',
#   'do',
#   'you',
#   'have',
#   'on',
#   'are',
#   'and',
#   'under',
#   'are',
#   'dear',
#   'must',
#   'may',
#   'suppose',
#   'no',
#   'go',
#   'so',
#   'will',
#   'stand',
#   'are',
#   'can',
#   'have',
#   'are',
#   'to',
#   'but',
#   'might',
#   'mean',
#   'know',
#   'are',
#   'heard',
#   'would',
#   'some',
#   'satisfaction',
#   'left',
#   'are',
#   'is',
#   'i',
#   'will',
#   'send',
#   'can',
#   'will',
#   'and',
#   'answered',
#   'said',
#   'dislike',
#   'mean',
#   'nor',
#   'please',
#   'like',
#   'know',
#   'write',
#   'in',
#   'heard',
#   'shall',
#   'take',
#   'will',
#   'give',
#   'all',
#   'and',
#   'must',
#   'think',
#   'and',
#   'go',
#   'may',
#   'and',
#   'for',
#   'an',
#   'were',
#   'curious',
#   'are',
#   'how',
#   'know',
#   'know',
#   'may',
#   'are',
#   'know',
#   'know',
#   'may',
#   'no',
#   'said',
#   'did',
#   'all',
#   'may',
#   'at',
#   'do',
#   'i',
#   "don't",
#   'know',
#   'do',
#   'are',
#   'know',
#   'may',
#   'every',
#   'tell',
#   'great',
#   'any',
#   'how',
#   'can',
#   'no',
#   'attended',
#   'be',
#   'certainly',
#   'have',
#   'the',
#   'saw',
#   'yes',
#   'were',
#   'know',
#   'see',
#   'were',
#   'had',
#   'like',
#   'liked',
#   'go',
#   'have',
#   'ever',
#   'were',
#   'conditionally',
#   ...]}

# %%
"""This module contains code from
Think Python by Allen B. Downey
http://thinkpython.com

Copyright 2012 Allen B. Downey
License: GNU GPLv3 http://www.gnu.org/licenses/gpl.html

"""

import sys
import string
import random

# global variables
suffix_map = {}        # map from prefixes to a list of suffixes
prefix = ()            # current tuple of words


def process_file(filename, order=2):
    """Reads a file and performs Markov analysis.

    filename: string
    order: integer number of words in the prefix

    Returns: map from prefix to list of possible suffixes.
    """
    fp = open(filename)
    skip_gutenberg_header(fp)

    for line in fp:
        for word in line.rstrip().split():
            process_word(word, order)


def skip_gutenberg_header(fp):
    """Reads from fp until it finds the line that ends the header.

    fp: open file object
    """
    for line in fp:
        if line.startswith('*END*THE SMALL PRINT!'):
            break


def process_word(word, order=2):
    """Processes each word.

    word: string
    order: integer

    During the first few iterations, all we do is store up the words; 
    after that we start adding entries to the dictionary.
    """
    global prefix
    if len(prefix) < order:
        prefix += (word,)
        return

    try:
        suffix_map[prefix].append(word)
    except KeyError:
        # if there is no entry for this prefix, make one
        suffix_map[prefix] = [word]


    prefix = shift(prefix, word)


def random_text(n=100):
    """Generates random wordsfrom the analyzed text.

    Starts with a random prefix from the dictionary.

    n: number of words to generate
    """
    # choose a random prefix (not weighted by frequency)
    start = random.choice(suffix_map.keys())
    
    for i in range(n):
        suffixes = suffix_map.get(start, None)
        if suffixes == None:
            # if the start isn't in map, we got to the end of the
            # original text, so we have to start again.
            random_text(n-i)
            return
        #print suffixes
        # choose a random suffix
        word = random.choice(suffixes)
        print word,
        start = shift(start, word)
        #print start


def shift(t, word):
    """Forms a new tuple by removing the head and adding word to the tail.

    t: tuple of strings
    word: string

    Returns: tuple of strings
    """
    return t[1:] + (word,)


def main(name, filename='', n=100, order=2, *args):
    try:
        n = int(n)
        order = int(order)
    except:
        print 'Usage: randomtext.py filename [# of words] [prefix length]'
    else: 
        process_file(filename, order)
        random_text(n)

# %%
main('emma.txt','emma.txt', 100, 3)
# Out:
# unfavourable likeness, to every morning visitor in Brunswick Square;--and, as I said, I did then forswear ever drawing any body again. But for Harriet's sake, or rather for my own, and as there are no husbands and wives in the case _at_ _present_, I will break my resolution now." Mr. Elton seemed very properly struck and delighted by the idea, and was repeating, "No husbands and wives in the case at present indeed, as you observe. Exactly so. No husbands and wives," with so interesting a consciousness, that Emma began to feel she had been saying to Mrs. Elton, and

# %%
import matplotlib.pyplot as plt
import math

def read_book(book):
    hist = {}
    fp = file(book)
    for this_line in fp:    
        this_line = this_line.replace('-', ' ')
        for this_word in this_line.split():
            # remove punctuation and convert to lowercase
            this_word = this_word.strip(string.punctuation + string.whitespace)
            this_word = this_word.lower()
            hist[this_word] = hist.get(this_word, 0) + 1
    return hist

def create_rank(hist):
    wordfreq = hist.values()
    wordfreq.sort(reverse=True)
    # enumerate the ranks and frequencies 
    rf = [(r+1, f) for r, f in enumerate(wordfreq)]
    #print rf
    return rf

def print_rank(rf):
    for r, f in rf:
        #print math.log(r), math.log(f)
        print r, f
    return

def plot_rank(rf, scale='log'):
    r, f = zip(*rf)
    plt.xscale(scale)
    plt.yscale(scale)
    plt.title('Zipf plot')
    plt.xlabel('rank')
    plt.ylabel('frequency')
    plt.plot(r, f, 'ro')
    plt.show()
    

def doit():
    hist = read_book('emma.txt')
    create_rank(hist)
    rf = create_rank(hist)
    plot_rank(rf)

# %%
doit()
